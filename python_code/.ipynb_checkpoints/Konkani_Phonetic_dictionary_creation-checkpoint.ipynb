# %% [markdown]
# '''
# latest modification on 21/07/2023
# Initial code: 27/05/2023
#
# Author: Swapnil Fadte
#
# This program is intended for creation of **lexicon/phonetic dictionary**.
#
#  Following are the steps in the program
#
#
# Part 1.   program take input as set of text files and extract all unique Devanagari word and store it as sorted list of words
# Part 2.   single or multiple phonetical traciption are generated and dictionary is created and stored as a text file.
#
# '''

# %%
#part 1: taking flie input and extracting unique devnagari words
import os
import sys
import regex as re

# taking input from file
# from google.colab import drive
# drive.mount('/content/content/drive')

#directory location data
data_path="/home/dcst/Desktop/Konkani_Phonetic_Dictionary/python_code/data"

# Folder Path
path = data_path
  
# Change the directory
os.chdir(path)
  
# Read text File
  
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        print(f.read())
  
# initialisation of parameters for getting unique words

merged_file= open("../merged_text_file.txt","w",encoding='UTF-8')
# iterate through all file
for file in os.listdir():
    # Check whether file is in text format or not
    if file.endswith(".txt"):
        file_path = f"{path}/{file}"
  
        # call read text file function
        #read_text_file(file_path)
        file=open(file_path,encoding='UTF-8')
        read_content= file.read()
        file.close()
        merged_file.write(read_content)

        
#print(merged_file.read())
merged_file.close()

#printing merged file content
#merged_file= open("merged_text_file.txt","r",encoding='UTF-8')
#print(merged_file.read())
#merged_file.close()
'''
with open("data/T1-0001.txt", "rt") as myFile:
  for myLine in myFile:
    print(myLine);
'''
    
#creating a file of unque words
src_file = open("../merged_text_file.txt","r")
tgt_file = open("../Unique_words.txt","w")

#read contents from file
file_text = src_file.read()

#list of uniquewords
unique_words = []

#clean characters other than devanagari
file_clean = re.sub('[\p{latin}\p{posix_punct}\d-]','',file_text)
#file_clean = re.sub('\ufeff','',file_clean)
file_clean = re.sub('ऽ','',file_clean)
#cases like च्च sometimes repsented as च̵ this may have been made
#to make it appear like च्च by combining charater च  ̵

#split text to words
words_in_file = file_clean.split()

#get unique words
for word in words_in_file:
    if word not in unique_words:
        unique_words.append(word)

#print 
#print(words_in_file)
unique_words.sort(reverse=False)

#tgt_file.write(str(unique_words))

for word in unique_words:
    #cases like च्च sometimes repsented as च̵ this may have been made
    #to make it appear like च्च by combining charater च  ̵
    #if ('̵'in word or '̶'in word or '̵'in word):
    if ('̵'in word or '̶'in word):
        continue
    else:
        tgt_file.write(word+"\n")

src_file.close()
tgt_file.close()
#print(unique_words)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 17>()
#      14 path = data_path
#      16 # Change the directory
# ---> 17 os.chdir(path)
#      19 # Read text File
#      21 def read_text_file(file_path):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/home/dcst/Desktop/Konkani_Phonetic_Dictionary/python_code/data'

# %%
#devnagari Konkani word to IPA conversion.

#setting path of file 
file_path="../Unique_words.txt"

#read words from file and store it in list
# opening the file in read mode
#my_file = open(file_path, 'r','utf-8')
my_file = open(file_path, 'r',encoding="utf-8")  

# reading the file
data = my_file.read()
  
# replacing end of line('/n') with ' ' and
# splitting the text it further when ' ' is seen.
word_list = data.replace('\n', ' ').split(" ")
  
# printing the data 
#print(word_list)
my_file.close()


#dictionary mapping initialisation
'''
mapping={'अ' : 'ə', 'आ' : 'a', 'ा' : 'a', 
         'इ' : 'i', 'ि' : 'i', 'ई' : 'i:', 'ी' : 'i', 
         'उ' : 'u', 'ु' : 'u', 'ऊ' : 'u:', 'ू' : 'u',
         'ए' : 'e', 'े' : 'e', 'ॲ' : 'ɛ', 'ऍ' : 'ɛ', 'ॅ' : 'ɛ', 
         'ओ' : 'o', 'ो' : 'o', 'ऑ' : 'ɔ', 'ॉ' : 'ɔ',
         'ऐ' : 'ɨj', 'ै' : 'ɨj', 'औ' : 'əu', 'ौ' : 'əu',
         'ऋ' : 'x', 'ृ' : 'x', 'ॠ' : 'X', 'ॄ' : 'X',
         'ऌ' : 'q', 'ॢ' : 'q','ॡ' : 'Q', 'ॣ' : 'Q',
         'ऎ' : 'e', 'ॆ' : 'e', 'ऒ' : 'o', 'ॊ' : 'o',
         'ँ' : 'M’', 'ं' : '◌̃', 'ः' : 'H',
         'क' : 'kə', 'ख' : 'kʰə', 'ग' : 'gə', 'घ' : 'gʱə', 'ङ' : 'ŋə', 
         'च' : 't͡ʃə', 'छ' : 'tʃʰə', 'ज' : 'd͡zə', 'झ' : 'dʒʱə', 'ञ' : 'ɲə',
         'ट' : 'ʈə', 'ठ' : 'ʈʰə', 'ड' : 'ɖə', 'ढ' : 'ɖʰə', 'ण' : 'ɳə', 
         'त' : 't̪ə', 'थ' : 't̪ʰə', 'द' : 'd̪ə', 'ध' : 'd̪ʰə', 'न' : 'nə', 
         'प' : 'pə', 'फ' : 'fə', 'ब' : 'bə', 'भ' : 'bʱə', 'म' : 'mə',
         'य' : 'jə', 'र' : 'rə', 'ल' : 'lə', 'व' : 'ʋə',
         'श' : 'ʃə', 'ष' : 'ʂə', 'स' : 'sə', 'ह' : 'ɦə',
         'ळ' : 'ɭə', 'ऴ' : 'Zaə', 'ॐ' : 'omə', '्' : '',
         'ऱ':'r','य़':'jə',
         '़़':'','ऽ':'','-':''
        }
'''
mapping={'अ' : 'ə', 'आ' : 'a', 'ा' : 'a', 
         'इ' : 'i', 'ि' : 'i', 'ई' : 'i:', 'ी' : 'i', 
         'उ' : 'u', 'ु' : 'u', 'ऊ' : 'u:', 'ू' : 'u',
         'ए' : 'e', 'े' : 'e', 'ॲ' : 'ɛ', 'ऍ' : 'ɛ', 'ॅ' : 'ɛ', 
         'ओ' : 'o', 'ो' : 'o', 'ऑ' : 'ɔ', 'ॉ' : 'ɔ',
         'ऐ' : 'ɨj', 'ै' : 'ɨj', 'औ' : 'əu', 'ौ' : 'əu',
         'ऋ' : 'x', 'ृ' : 'x', 'ॠ' : 'X', 'ॄ' : 'X',
         'ऌ' : 'q', 'ॢ' : 'q','ॡ' : 'Q', 'ॣ' : 'Q',
         'ऎ' : 'e', 'ॆ' : 'e', 'ऒ' : 'o', 'ॊ' : 'o',
         'ँ' : 'M’', 'ं' : '◌̃', 'ः' : 'H',
         'क' : 'kə', 'ख' : 'kʰə', 'ग' : 'gə', 'घ' : 'gʱə', 'ङ' : 'ŋə', 
         'च' : 't͡ʃə', 'छ' : 'tʃʰə', 'ज' : 'd͡zə', 'झ' : 'd͡zʱə', 'ञ' : 'ɲə',
         'ट' : 'ʈə', 'ठ' : 'ʈʰə', 'ड' : 'ɖə', 'ढ' : 'ɖʰə', 'ण' : 'ɳə', 
         'त' : 'tə', 'थ' : 'tʰə', 'द' : 'də', 'ध' : 'dʰə', 'न' : 'nə', 
         'प' : 'pə', 'फ' : 'fə', 'ब' : 'bə', 'भ' : 'bʱə', 'म' : 'mə',
         'य' : 'jə', 'र' : 'rə', 'ल' : 'lə', 'व' : 'və',
         'श' : 'ʃə', 'ष' : 'ʂə', 'स' : 'sə', 'ह' : 'hə',
         'ळ' : 'ɭə', 'ऴ' : 'Zaə', 'ॐ' : 'omə', '्' : '',
         'ऱ':'r','य़':'jə',
         '़़':'','ऽ':'','-':''
        }
#final dictionary file
file = open("../phonetic_dictionary.txt", "w",encoding="utf-8")

#giving words from list for phonetic transcription
for words in word_list:
    #devnagari_word="कोंकणी"
    devnagari_word=words
    IPA_transcription=""

    for i in devnagari_word:
        #print(i)
        #IPA_transcription+=mapping.get(i)
        if (i=="ं"):
            #last=IPA_transcription[-1]
            #IPA_transcription=IPA_transcription[:-1]+mapping.get(i)+last
            IPA_transcription+= '\u0303' #combining nasalisation to phone
            #print("special case:",IPA_transcription)
            continue
        if (i=="्"or i == 'ा' or i == 'ि' or i == 'ी' or i == 'ु' 
            or i == 'ू' or i == 'े' or i == 'ॅ' or i == 'ो' or i == 'ॉ'
            or i == 'ै' or i == 'ौ' or i == 'ौ' or i == 'ृ' or i == 'ॄ' or 
            i == 'ॢ' or i == 'ॣ' or i == 'ॆ' or i == 'ॊ'):
        
            IPA_transcription=IPA_transcription[:-1]+mapping.get(i)
            #print("special case:",IPA_transcription)
            continue
        if(i=='़'or i=='ऽ' or i=='-'):
            continue
        if (i=='\u200d'):# ZERO WIDTH JOINER (‍) for words like तिसर्‍या
            continue
        # problem with character combination च्च need to sorted
        else:
            IPA_transcription+=mapping.get(i)
    
        #print(mapping.get(i))
    #print(IPA_transcription)
    #removing "ə" from last charater in the word
    if len(IPA_transcription)>0:
        if (IPA_transcription[-1]=='ə'):
            IPA_transcription=IPA_transcription[:-1]
        #print(IPA_transcription)
    line=devnagari_word+" "+IPA_transcription+"\n"
    file.write(line)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 9>()
#       4 file_path="../Unique_words.txt"
#       6 #read words from file and store it in list
#       7 # opening the file in read mode
#       8 #my_file = open(file_path, 'r','utf-8')
# ----> 9 my_file = open(file_path, 'r',encoding="utf-8")
#      11 # reading the file
#      12 data = my_file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Unique_words.txt'

# %%
#Code for cheking hiiden unicode characters in devnagari words
#!/usr/bin/python -tt
# -*- coding: utf-8 -*-
import unicodedata
#str="तिसर्‍या  तिसर्या"
#str="उखलचो"
#str="उच̵टन"
#str="उखलतना"
#str='उच̶'
#str='उच̵'
#str='होकर'
str='होंवर्यांतनी'
print(len(str))
for i in str:
    print ((i))
import re
regex = re.compile(u'[^\u092E-\u092E]+')
#result = regex.findall(u'तिसर्‍या')
result = regex.findall(u'उच̶')
print(result)
# Out:
# 12
# ह
# ो
# ं
# व
# र
# ्
# य
# ा
# ं
# त
# न
# ी
# ['उच̶']

# %%
#code for testing performance of dictionary
def alignTwoFiles(filename):
    dictforkonkaniIPA={}
    
    fileIPA_text=open("../performace_mesearure/data/Phonectic_annaotated_Konkani_IPA_text.txt","r",encoding="utf8")
    fileKonkani_text=open("../performace_mesearure/data/Phonetic_annaotated_Konkani_text.txt","r",encoding="utf8")
    filealign=open("../align/"+filename,"w",encoding="utf8")
    fileIPA_lines=fileIPA_text.readlines()
    fileKonkani_text_lines=fileKonkani_text.readlines()
    
    #print(len(fileKonkani_text_lines))
    #print(len(fileIPA_lines))
    
    for i in range(len(fileKonkani_text_lines)):
        
        
        konkani_text_words=fileKonkani_text_lines[i].rstrip(" \n").split()
        fileIPA_words=fileIPA_lines[i].rstrip(" \n").split()
        '''
        
        if len(konkani_text_words)!=len(fileIPA_words):
            print("line number", i)
            print(len(konkani_text_words))
            print(konkani_text_words)
            print(len(fileIPA_words))
            print(fileIPA_words)
        '''
        
        for ind in range(len(konkani_text_words)):
            concat=konkani_text_words[ind]+"#"+fileIPA_words[ind]
            if concat in dictforkonkaniIPA:
                dictforkonkaniIPA[concat]=dictforkonkaniIPA.get(concat)+1
            else:
                dictforkonkaniIPA[concat]=1
        
    for key in dictforkonkaniIPA:
        filealign.write(key)
        #filealign.write("#"+value)
        filealign.write("\n")
    filealign.close() 
    fileIPA_text.close()
    fileKonkani_text.close()
    
alignTwoFiles("alignkonkaniText_IPA.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 44>()
#      41     fileIPA_text.close()
#      42     fileKonkani_text.close()
# ---> 44 alignTwoFiles("alignkonkaniText_IPA.txt")
#
# Input In [3], in alignTwoFiles(filename)
#       2 def alignTwoFiles(filename):
#       3     dictforkonkaniIPA={}
# ----> 5     fileIPA_text=open("../performace_mesearure/data/Phonectic_annaotated_Konkani_IPA_text.txt","r",encoding="utf8")
#       6     fileKonkani_text=open("../performace_mesearure/data/Phonetic_annaotated_Konkani_text.txt","r",encoding="utf8")
#       7     filealign=open("../align/"+filename,"w",encoding="utf8")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../performace_mesearure/data/Phonectic_annaotated_Konkani_IPA_text.txt'

# %%
def searchforIPAtranscription():
    fileIPATransoutput=open("../performace_mesearure/data/phonetic_dictionary.txt","r",encoding="utf8")
    fileGS_IPAtext=open("../performace_mesearure/data/GS_IPAtext.txt","w",encoding="utf8")
    fileGS_IPAtext_NOTexisting=open("../performace_mesearure/data/GS_IPAtext_NOtexisting.txt","w",encoding="utf8")
    filealigned=open("../align/alignkonkaniText_IPA.txt","r",encoding="utf8")
    fileIPATransoutput_lines=fileIPATransoutput.readlines()
    filealigned_lines=filealigned.readlines()
    
    list_konk_text=[]
    list_IPA_text=[]
    for line in filealigned_lines:
        line=line.rstrip("\n")
        word=line.split("#")
        list_konk_text.append(word[0])
        list_IPA_text.append(word[1])
        
    for line in fileIPATransoutput_lines:
        word=line.split(" ")
        if word[0] in list_konk_text:
            ActualIPAword=list_IPA_text[list_konk_text.index(word[0])]
            fileGS_IPAtext.write(word[0]+" ")
            fileGS_IPAtext.write(ActualIPAword+" ")
            fileGS_IPAtext.write(word[1])
        else:
            fileGS_IPAtext_NOTexisting.write(word[0]+"\n")
    
    fileGS_IPAtext.close()   
    fileGS_IPAtext_NOTexisting.close()
    filealigned.close()
    fileIPATransoutput.close()

searchforIPAtranscription()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 32>()
#      29     filealigned.close()
#      30     fileIPATransoutput.close()
# ---> 32 searchforIPAtranscription()
#
# Input In [4], in searchforIPAtranscription()
#       1 def searchforIPAtranscription():
# ----> 2     fileIPATransoutput=open("../performace_mesearure/data/phonetic_dictionary.txt","r",encoding="utf8")
#       3     fileGS_IPAtext=open("../performace_mesearure/data/GS_IPAtext.txt","w",encoding="utf8")
#       4     fileGS_IPAtext_NOTexisting=open("../performace_mesearure/data/GS_IPAtext_NOtexisting.txt","w",encoding="utf8")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../performace_mesearure/data/phonetic_dictionary.txt'

# %%
def accuracy():
    count=0
    fileGS_IPAtext=open("../performace_mesearure/data/GS_IPAtext.txt","r",encoding="utf8")
    fileGS_err=open("../performace_mesearure/data/err.txt","w",encoding="utf8")
    fileGS_IPAtext_lines=fileGS_IPAtext.readlines()
    for line in fileGS_IPAtext_lines:
        line=line.rstrip("\n")
        word=line.split(" ")
        if word[1]==word[2]:
            count=count+1
        else:
            fileGS_err.write(line+"\n")
    fileGS_err.close()
    print("count",count)
    print("len(fileGS_IPAtext_lines)",len(fileGS_IPAtext_lines))
    acc=count/len(fileGS_IPAtext_lines)*100
    print("Word Acc",acc)
    
accuracy()
# Out:
# count 106
# len(fileGS_IPAtext_lines) 312
# Word Acc 33.97435897435898

# %%
#script for converting devnagari words to unicode.
word="ताणें"
print(word)
# Out:
# ताणें

# %%
# Script to rename files 
# from google.colab import drive
# drive.mount('/content/content/drive') 
# drive.mount('/content/ContemporaryTextFiles/')

import os 
count = 0
files = os.listdir('ContemporaryTextFiles')
for item in files:
  count = count+1
print(count)

#src = os.listdir('ContemporaryTextFiles')
src = os.listdir('ContemporaryTextFiles')[1]
# print(src)
dir = 'ContemporaryTextFiles/'
index = 0
for item in files:
  while index < count:
    src = os.listdir('ContemporaryTextFiles')[index]
    # START FILE OPERATION
    print(src)
    os.rename(dir+src, 'file_'+str(index)+'.txt')
    print('Renamed...')
    # with open('ContemporaryTextFiles/'+src, 'rt') as myFile:
    #   for myLine in myFile:
    #     print(myLine);
    #     break;
    #  START FILE OPERATION
    index = index+1



# print('Updated Files')
# print(os.listdir('ContemporaryTextFiles'))

# count = os.listdir('ContemporaryTextFiles').count()
# print(count)
# os.rename()

# %%
# Script to Uniquely extract unique tokens 
import os 
count = 0
files = os.listdir('ContemporaryTextFiles')
for item in files:
  count = count+1
print(count)

#src = os.listdir('ContemporaryTextFiles')
src = os.listdir('ContemporaryTextFiles')[1]
# print(src)
dir = 'ContemporaryTextFiles/'
index = 0
for item in files:
  while index < count:
    src = os.listdir('ContemporaryTextFiles')[index]
    # START FILE OPERATION
    print(src)
    os.rename(dir+src, 'file_'+str(index)+'.txt')
    print('Renamed...')
    # with open('ContemporaryTextFiles/'+src, 'rt') as myFile:
    #   for myLine in myFile:
    #     print(myLine);
    #     break;
    #  START FILE OPERATION
    index = index+1

# %%
# Program to Extract Unique words from English Text
dir = 'ContemporaryTextFiles/';
text_file = open(dir+'data.txt', 'r')
text = text_file.read()

#cleaning
text = text.lower()
words = text.split()
words = [word.strip('.,!;()[]') for word in words]
words = [word.replace("'s", '') for word in words]
words = [word.replace("'ऽ", '') for word in words]

#finding unique
unique = []
for word in words:
    if word not in unique:
        unique.append(word)

#sort
unique.sort()

#print
print(unique)
# WORKING
# Out:
# ['a', 'across', 'an', 'apple', 'away', 'beside', 'big', 'came', 'cat', 'company', 'day', 'device', 'doctor', 'fat', 'is', 'keeps', 'office', 'owns', 'road', 'the', 'very']

# %%
# Program to Extract Unique words from Konkani Text
dir = 'InputFiles/';
text_file = open(dir+'file_0.txt', 'r')
text = text_file.read()

#cleaning
# text = text.lower()
words = text.split()
words = [word.strip('.,!;()[]') for word in words]
words = [word.replace("'s", '') for word in words]

#finding unique
unique = []
for word in words:
    if word not in unique:
        unique.append(word)

#sort
unique.sort()

#print
print(unique)
# WORKING
# Out:
# ['11/25/2009', '12:00:00', '16', '21To50', '24-bit', '48.00000', '50', '::', 'ADa', 'ADacO', 'AGE', 'ALasa', 'AM', 'AdIM', 'AdalyA', 'Adara', 'AgrO', 'AmI', 'AmacE', 'AmacEM', 'AmacO', 'AnI', 'ApalE', 'AsA', 'AsUMka', 'AsacE', 'AsacOca', 'AsapAka', 'AsapAkaca', 'AsapAvana', 'AshillE', 'AtAM', 'AyajUya', 'Ayaja', 'AyalyA', 'BIT', 'Battery', 'CHANNEL', 'CONTENT', 'CUNCOLIM', 'Contemporary', 'DATE', 'DIALECT', 'DISTRICT', 'Devanagari', 'Dr', 'EDIROL', 'EDUCATION', 'EDUCATIONAL', 'ELEMENTRY', 'ENVIRONMENT', 'EkAdEM', 'EkE', 'EkUca', 'Eka-', 'FILE', 'FREQUENCY', 'Female', 'GENDER', 'GOA', 'GROUP', 'Goa', 'ID', 'Konkani', 'LANGUAGE', 'LDC-IL_Scheduled_Konkani_Female_21To50_Contemporary', 'Linear', 'MANUFACTURER', 'MOTHER', 'Master', 'NAME', 'OF', 'Office', 'OtO', 'PCM', 'PLACE', 'POWER', 'QUALIFICATION', 'R-09', 'RATE', 'READ', 'RECORDED', 'RECORDER', 'RECORDING', 'Roland', 'SAMPLING', 'SCRIPT', 'SOURCE', 'SOUTH', 'SP-0089', 'SPEAKER', "SPEAKER'S", 'STATE', 'South', 'Stereo', 'T1-0089', 'TEXT', 'TONGUE', 'TRANSLITERATION', 'TYPE', 'Text-T1', 'Text-T1_SP-0089_T1-0089.wav', 'aDakallI', 'aMtarillyA', 'aTakE', 'adhikAra', "ajnj'AnA", 'alkaline', 'alpakAlIna', 'amErikEMtalO', 'anAcArAMka', 'anyAyAcO', 'apEkSA', 'apurNatAyEcI', 'arthAna', 'arthIka', 'artha', 'asO', 'asalyA', 'ashE', 'ashEM', 'ashEMya', 'ashI', 'ashyA', 'bAyalAMkaya', 'bEkAyadEshIra', 'badallyAta', 'barAbara', 'barI', 'bhAsAbhAsa', 'bhAshEMta', 'bhAvAna', 'bhAyalyAM', 'bhAyarAvacI', 'bhEdAbhEdA', 'bhImasmritI', 'bhOgatA', 'bhaMga', 'bharapAcO', 'bhitaralE', 'bits/sample', 'buddIcE', 'buddIvAda', 'byO', 'caDashE', 'caDashyA', 'calacEM', 'calata', 'cukIcyO', 'dEkhUna', 'dEshabhaktIcO', 'dEvabhaktIka', 'dEvadEva', 'dIrghakAlIna', 'davaralyA', 'dharalO', 'dharmAM', 'dharmAnI', 'dharmAna', 'dharma', 'dharmagraMtha', 'dharmavAdyAMka', 'dilA', 'dilI', 'dillO', 'disatA', 'dishTI', 'divacE', 'divacO', 'divapAka', 'dukhkha', 'durdaiva', 'durjana', 'durjanapaNAcyO', 'durlakSIta', 'dusyAMka', 'gAjOvapI', 'gElI', 'gOMyAMta', 'gOMyacyA', 'gajAlI', 'gajAla', 'garaja', 'ghEtAta', 'ghEtalyA', 'ghOva', 'ghaDaTAta', 'ghaTaka', 'hAMcE', 'hAtUMta', 'hAtUMtalEM', 'hE', 'hEM', 'hI', 'hO', 'haLadIkukamAcI', 'hajArAMnI', 'hukumAcO', 'italI', 'jAMkAM', 'jANavikAya', 'jAcyA', 'jAllIM', 'jAllO', 'jAlyAra', 'jAlyAta', 'jAtA', 'jAtAlE', 'jAvana', 'jAya', 'jE', 'jEnnA', 'jO', 'jarUra', 'jasO', 'jashI', 'jashyO', 'jhiDakArupayeyA', 'jhujuyA', 'jyOtirAva', 'kALA', 'kAMya', 'kAMyaca', 'kAryAvaLIMnI', 'kAya', 'kElA', 'kEllO', 'kHz', 'kONEMya', 'kONa', 'kSEtrAMtalE', 'kaDEna', 'kaDalyAna', 'kalpanA', 'kalyANA', 'karInashI', 'karUM', 'karaNyAMka', 'karacO', 'karacOca', 'karapA', 'karapI', 'karatAta', 'karinAsatanA', 'karinAta', 'karma', 'karmakAMDAM', 'karmakAMDAMcEM', 'karmakAMDa', 'kartavyAM', 'kartavya', 'karupayeNA', 'kasalOca', 'khAtIra', 'khAtIracO', 'khyAnIca', 'kistAMva', 'krAMtI?', 'krAMtIcO', 'kritInI', 'lAgUna', 'lAsalyAra', 'lEgIta', 'lOhiyA', 'lOhiyAMcyA', 'lOhiyAna', 'lOka', 'laDhO', 'lagna', 'lagnapaddata', 'lagna’', 'lavacIka', 'lavacIkatAya', 'lhavU', 'lubADaTAta', 'mAMDalyAta', 'mAgIra', 'mAgUna', 'mAnapI', 'mAnatAta', 'mAnavatEcE', 'mAnuyA', 'mAphI', 'mAracO', 'mAtashI', 'ma', 'madIM', 'mamanusmritI', 'manIsakuLayEcEra', 'manIsakuLayEcyA', 'manIsapaNAcIM', 'manashAM', 'manusmritI', 'matAna', 'mhAkA', 'mhUNa', 'mhaNaTAlE', 'mhaNapAcEM', 'mulabhUta', 'musalamAna', 'nA', 'nAkA', 'nAsata', 'nAshillIM', 'nEmillOca', 'nEphA', 'naitIkatAya', 'naja', 'navI', 'nhayakArUna', 'nhayakAralyAMta', 'nishkrIya', 'nyAyAlayAMta', 'pAtaLAyatAta', 'pOkaLEka', 'pOkaLI', 'pUNa', 'paDaTA', 'paDaTalO.’', 'paLOvayA’', 'paddatIMta', 'paddata', 'paryAya', 'phATalO', 'phAskEMta', 'phAvO', 'phakata', 'phikEM', 'phuDEM', 'phuDalO', 'phuDyAnI', 'phulEna', 'prAgatIka', 'prEraNEcO', 'prasna', 'pratikAra', 'pratyakSa', 'pravEshabaMdI', 'pujArI', 'punarupayejjIvana', 'purayata', 'purayatapaNa', 'rAga', 'rAjakI', 'rAjanitI.’', 'rOkhaDOca', 'rupayeDhIgata', 'sAMgalyAMta', 'sAMgatAta', 'sANIra', 'sAdE-sOMpEM', 'sAdI', 'sAdhanA' ...

# %%
# Program to Extract Unique words from Konkani Text
import os

# print(os.getcwd())

# from google.colab import drive
# drive.mount('/content/gdrive/') 

# print(os.getcwd())

# os.system('cd ')

# dir = 'data/';
# text_file = open(dir+'T1-0010.txt', 'r')
# text = text_file.read()

with open('Input/SortedToBeSorted.txt', 'rt') as myFile:
  for item in myFile:
    # print(item)
    text = item;

    #cleaning
    text = text.lower()
    words = text.split()
    words = [word.strip('.,!;()[]') for word in words]
    words = [word.replace("'s", '') for word in words]


    #finding unique
    unique = []
    for word in words:
        if word not in unique:
            unique.append(word)

    #sort
    unique.sort()

    #print
    print(unique)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['आसतात']
# ['आसतात']
# ['आसतात']
# ['आसतात']
# ['आसना']
# ['आसनात']
# ['आसपाक']
# ['आसपाक']
# ['आसरो']
# ['आसले']
# ['आसलें']
# ['आसल्यार']
# ['आसल्यार']
# ['आसल्यार']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा']
# ['आसा?']
# ['आसा?']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसात']
# ['आसुनूय']
# ['आसूं']
# ['आसून']
# ['आसून']
# ['आस्त']
# ['आस्था']
# ['आस्थांपनां']
# ['इंगळ्याचेर']
# ['इंच']
# ['इंडिया']
# ['इंदूरच्या']
# ['इंधन']
# ['इकॉनॉमींत']
# ['इज्जतीक']
# ['इतले']
# ['इतलें']
# ['इतलो']
# ['इतलोच']
# ['इतिहास']
# ['इतिहासाचि']
# ['इतिहासाची']
# ['इत्साशक्त']
# ['इन्फ्रा']
# ['इन्फ्राचे']
# ['इबाडटा']
# ['इबाडटात']
# ['इबाडटात”']
# ['इलेक्ट्रॉमॅग्नेटिक']
# ['इश्ट']
# ['इश्ट']
# ['इस्रायला']
# ['इस्लामिक']
# ['उक्तायत']
# ['उक्तायल्या']
# ['उक्तावंक']
# ['उक्तीं']
# ['उक्ते']
# ['उजवाडायिल्ली']
# ['उजो']
# ['उठले']
# ['उठाक']
# ['उठाव']
# ['उठून']
# ['उठ्ठां-बसतां']
# ['उडपा']
# ['उडयतले']
# ['उडयलीं']
# ['उडयलें']
# ['उडयलो']
# ['उडयल्या']
# ['उड्डाण']
# ['उणाव']
# ['उणी']
# ['उणे']
# ['उणेंच']
# ['उणो']
# ['उणो']
# ['उणो']
# ['उणो']
# ['उण्या']
# ['उतरां']
# ['उतरांतल्यान']
# ['उतलीच']
# ['उत्तर']
# ['उत्तर']
# ['उत्तर']
# ['उत्तराधिकारी']
# ['उत्पादन']
# ['उत्सूकताय']
# ['उदक']
# ['उदक']
# ['उदक']
# ['उदक']
# ['उदकाक']
# ['उदरगत']
# ['उदरगती']
# ['उदरगतीचे']
# ['उदरगतीचे']
# ['उदरगतीचें']
# ['उदरगतीचो']
# ['उदात्तीकरण']
# ['उदार']
# ['उदारमतवाद']
# ['उदाहरणां']
# ['उदाहारणां']
# ['उद्देग']
# ['उद्देगीक']
# ['उद्देश']
# ['उद्वेग']
# ['उन्मादान']
# ['उन्मादी']
# ['उपभोग']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांत']
# ['उपरांतच्या']
# ['उपाय?']
# ['उपेक्षीत']
# ['उपेक्षेन']
# ['उपेगाचें']
# ['उबारतना']
# ['उबारपाचो']
# ['उबारिल्ले']
# ['उबीं']
# ['उबे']
# ['उबे']
# ['उबो']
# ['उबो']
# ['उबो']
# ['उबो']
# ['उमेद']
# ['उमेदीक']
# ['उमेदीचेर']
# ['उरतलीं']
# ['उरतले']
# ['उरताच']
# ['उरलां']
# ['उरली']
# ['उरिल्ले']
# ['उरूंक']
# ['उर्बा']
# ['उलयतले']
# ['उलोवंक']
# ['उलोवपाक']
# ['उल्लंघन']
# ['उस्मानाबादाक']
# ['ए']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एक']
# ['एकचार']
# ['एकचार']
# ['एकचाराची']
# ['एकठांय']
# ['एकदां']
# ['एकर']
# ['एकसारकेंपण']
# ['एकसारकेंपण']
# ['एका']
# ['एका']
# ['एका']
# ['एका']
# ['एका']
# ['एका']
# ['एकामेकांचे']
# ['एकूय']
# ['एके']
# ['एके']
# ['एके']
# ['एके']
# ['एके']
# ['एक्काय']
# ['एक्कूय']
# ['एख']
# ['एखदां']
# ['एनजीओ']
# ['एसएमएस']
# ['ऑक्टोबर']
# ['ऑगस्ट']
# ['ऑगस्टाक']
# ['ऑगस्टूय']
# ['ऑफ']
# ['ऑर्डरीय']
# ['ओंपारेचो']
# ['ओग्गी']
# ['ओग्गी']
# ['ओठ']
# ['ओठार']
# ['ओतो']
# ['ओपार']
# ['कंत्रांटांक']
# ['कंत्राटी']
# ['कंपनी']
# ['कंपन्यांक']
# ['कंपन्यांनी']
# ['कंपन्यो']
# ['कट्टर']
# ['कठीण']
# ['कठीण']
# ['कठीण']
# ['कडची']
# ['कडलयान']
# ['कडली']
# ['कडली']
# ['कडलीं']
# ['कडल्या']
# ['कडल्यान']
# ['कडल्यान']
# ['कडल्यान']
# ['कडल्यान']
# ['कडल्यान']
# ['कडल्यान']
# ['कडल्यान']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कडेन']
# ['कड्डणां']
# ['कणकणी']
# ['कणो']
# ['कदरेन']
# ['कदेल']
# ['कदेलाक']
# ['कदेलाक']
# ['कदेलाक']
# ['कदेलाचेर']
# ['कन्यापुत्र']
# ['कपातीचो']
# ['कबीर']
# ['कमेंटस्']
# ['करची']
# ['करची']
# ['करची']
# ['करचीच']
# ['करचे']
# ['करचें']
# ['करचें']
# ['करचें']
# ['करचो']
# ['करणी']
# ['करणे']
# ['करणे']
# ['करणेक']
# ['करणेचे']
# ['करणेचेच']
# ['करण्यां']
# ['करतना']
# ['करतले']
# ['करतल्या']
# ['करतल्यांक']
# ['करता']
# ['करता']
# ['करता']
# ['करतात']
# ['करतात']
# ['करतात']
# ['करतात']
# ['करतात']
# ['करताले']
# ['करना']
# ['करप']
# ['करप']
# ['करप']
# ['करप']
# ['करपा']
# ['करपा']
# ['करपा']
# ['करपांत']
# ['करपाक']
# ['करपाक']
# ['करपाक']
# ['करपाक']
# ['करपाक']
# ['करपाक']
# ['करपाक']
# ['करपाक']
# ['करपाक']
# ['करपाची']
# ['करपाची']
# ['करपाची']
# ['करपाची']
# ['करपाची']
# ['करपाचे']
# ['करपाचे']
# ['करपाचे']
# ['करपाचें']
# ['करपाचें']
# ['करपाचें']
# ['करपाचें']
# ['करपाचो']
# ['करपाचो']
# ['करपाचो']
# ['करपाचो']
# ['करपाचो']
# ['करपाच्या']
# ['करपी']
# ['करपी']
# ['करपी']
# ['करप्यांक']
# ['करिना']
# ['करीत']
# ['करीत']
# ['करीत']
# ['करीत']
# ['करीत']
# ['करुणानिधीचे']
# ['करुणानिधीचो']
# ['करुणानिधीच्या']
# ['करुणानिधीन']
# ['करुणानिधीय']
# ['करुया']
# ['करूं']
# ['करूं']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['करून']
# ['कर्तुत्व']
# ['कर्तुत्वाचीं']
# ['कर्तुपांचो']
# ['कर्तुबा']
# ['कर्तुबांत']
# ['कर्मचाऱयांक']
# ['कर्मचाऱयांनी']
# ['कर्माचें']
# ['कल']
# ['कलंकधुवून']
# ['कलकलो']
# ['कलान']
# ['कल्पकताय']
# ['कळना']
# ['कळप']
# ['कळप']
# ['कळप']
# ['कळपांतल्या']
# ['कवळची']
# ['कशी?']
# ['कशें']
# ['कशें']
# ['कशें']
# ['कश्टांची']
# ['कसरत']
# ['कसलयोच']
# ['कसलीच']
# ['कसले']
# ['कसलेंय']
# ['कसलो']
# ['कसलोच']
# ['कसलोच']
# ['कसलोच']
# ['कसा']
# ['कसो']
# ['का']
# ['काँग्रेस']
# ['काँग्रेस']
# ['काँग्रेसचो']
# ['काँग्रेसीक']
# ['काँग्रेसीचो']
# ['काँग्रेसीच्या']
# ['काँग्रेसीन']
# ['कांडप्यांचो']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांय']
# ['कांयच']
# ['कांयच']
# ['कांयच']
# ['कांयच']
# ['कांयच']
# ['कांयच']
# ['कांसवाचे']
# ['कागाळ']
# ['काटशहाच्या']
# ['काडटात']
# ['काडप']
# ['काडपाक']
# ['काडपाक']
# ['काडपाक']
# ['काडपाची']
# ['काडपाची']
# ['काडपाची']
# ['काडपाचे']
# ['काडपाचें']
# ['काडपाचो']
# ['काडपाचो']
# ['काडला']
# ['काडला']
# ['काडलो']
# ['काडल्या']
# ['काडून']
# ['काडून']
# ['काडून']
# ['काणीच']
# ['कातर']
# ['कातरल्यांत']
# ['कानाची']
# ['काम']
# ['काम']
# ['काम']
# ['काम']
# ['काम']
# ['काम']
# ['कामत']
# ['कामत']
# ['कामाची']
# ['काय']
# ['काय']
# ['काय']
# ['काय']
# ['काय']
# ['काय']
# ['काय']
# ['काय']
# ['काय']
# ['काय']
# ['काय?']
# ['कायदेशीर']
# ['कायशांवांत']
# ['कारण']
# ['कारण']
# ['कारण']
# ['कारण']
# ['कारण']
# ['कारण']
# ['कारण']
# ['कारण']
# ['कारण']
# ['कारणां']
# ['कारणाक']
# ['कारणूय']
# ['कार्यकर्ते']
# ['कार्यकर्त्यांच्या']
# ['कार्यालयांचेर']
# ['काल']
# ['कालखंड']
# ['कालबाह्म']
# ['कालांतरान']
# ['काळ']
# ['काळ']
# ['काळजांय']
# ['काळांत']
# ['काळांत']
# ['काळांत']
# ['काळांत']
# ['काळीज']
# ['काळो']
# ['काळ्या']
# ['कावलांत']
# ['कावलांत']
# ['कावलांत']
# ['किजिल']
# ['किजिलां']
# ['किजिलां']
# ['कितली']
# ['कितलींशींच']
# ['कितलींशींच']
# ['कितले']
# ['कितलें']
# ['कितलेंय']
# ['कितलेंय']
# ['कितलो']
# ['कितलो']
# ['कितलो']
# ['किता']
# ['किते']
# ['कितें']
# ['कितें']
# ['कितें']
# ['कितें']
# ['कितें']
# ['कितें']
# ['कितें']
# ['कितें']
# ['कितें']
# ['कितें?']
# ['कितें?']
# ['कितेंय']
# ['कित्याक']
# ['कित्याक']
# ['कित्याक']
# ['कित्याक']
# ['कित्याक']
# ['कित्याक?']
# ['कित्याचेर']
# ['किमि']
# ['किमिचेर']
# ['किरण']
# ['किरवंट']
# ['किलो']
# ['की']
# ['की']
# ['की']
# ['कीक']
# ['कीक']
# ['कीक']
# ['कीची']
# ['कीचो']
# ['कीच्या']
# ['कीन']
# ['कील']
# ['कुरतडपाक']
# ['कुरूप']
# ['कुशीक']
# ['कुशीक']
# ['कुशीक']
# ['कुशीक']
# ['कुशीक']
# ['कुस्तार']
# ['कुस्तीवीर']
# ['कृती']
# ['केंद्र']
# ['केंद्रबिंदू']
# ['केंद्रांतलें']
# ['केंद्रीय']
# ['केंद्रीय']
# ['केंद्रीय']
# ['केन्ना']
# ['केन्ना']
# ['केन्ना']
# ['केन्नाच']
# ['केन्नाच']
# ['केला']
# ['केला']
# ['केला?']
# ['केलां']
# ['केली']
# ['केली']
# ['केली']
# ['केली']
# ['केली']
# ['केले']
# ['केले']
# ['केलें']
# ['केलो']
# ['केलो']
# ['केलो']
# ['केलो']
# ['केल्या']
# ['केल्या']
# ['केल्या']
# ['केल्या']
# ['केल्या']
# ['केल्ली']
# ['केल्ली']
# ['केल्ली']
# ['केल्ली']
# ['केल्ले']
# ['केल्ले']
# ['केल्ले']
# ['केल्ले']
# ['केल्लो']
# ['केल्लो']
# ['केल्ल्या']
# ['केस्तांवांत']
# ['कोटी']
# ['कोटी']
# ['कोटींक']
# ['कोटींचो']
# ['कोटींच्या']
# ['कोडा']
# ['कोडा']
# ['कोडाचे']
# ['कोडाचें']
# ['कोडाच्या']
# ['कोडाच्या']
# ['कोडान']
# ['कोडान']
# ['कोडानय']
# ['कोडू']
# ['कोण']
# ['कोण']
# ['कोण']
# ['कोण']
# ['कोण']
# ['कोणा']
# ['कोणाक']
# ['कोणाकूय']
# ['कोणाकूय']
# ['कोणाचें']
# ['कोणाचें']
# ['कोणाचो']
# ['कोणाचो']
# ['कोणाचोय']
# ['कोणूच']
# ['कोणे']
# ['कोणे']
# ['कोणेंय']
# ['कोनशांनी']
# ['कोनशे']
# ['कोलकाता']
# ['कोलती']
# ['क्या']
# ['क्यी']
# ['क्रियाशील']
# ['क्षीण']
# ['खंड']
# ['खंत']
# ['खंय']
# ['खंयचें']
# ['खंयचेय']
# ['खंयच्यान']
# ['खंयच्यान']
# ['खटकता']
# ['खणींच्या']
# ['खणींतलें']
# ['खणींनी']
# ['खबर']
# ['खबर']
# ['खबर']
# ['खर']
# ['खर']
# ['खरी']
# ['खरी']
# ['खरें']
# ['खरें']
# ['खरें']
# ['खरें?']
# ['खरो']
# ['खरो']
# ['खवळी']
# ['खवळीं']
# ['खांची']
# ['खांद्यार']
# ['खांद्यार']
# ['खाजगी']
# ['खाजगी']
# ['खाणांच्यो']
# ['खाता']
# ['खातीं']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीर']
# ['खातीरचे']
# ['खाते']
# ['खातें']
# ['खातें']
# ['खातें']
# ['खात्याचे']
# ['खात्याचें']
# ['खात्याच्या']
# ['खात्याच्यो']
# ['खात्यान']
# ['खात्री']
# ['खात्री']
# ['खात्री']
# ['खापवी']
# ['खामसुत्रें']
# ['खामसुत्र्याच्यो']
# ['खाला']
# ['खाल्ल्या']
# ['खावडीचे']
# ['खावपाची']
# ['खावपाचे']
# ['खावपाचे']
# ['खाशेलो']
# ['खासदारांचो']
# ['खिन']
# ['खीणभर']
# ['खुद्द']
# ['खुद्द']
# ['खुद्ध']
# ['खुपत']
# ['खुरीस']
# ['खूब']
# ['खूब']
# ['खूब']
# ['खूब']
# ['खूब']
# ['खूब']
# ['खूबच']
# ['खेड्यांत']
# ['खेपे']
# ['खेळां']
# ['खेळ्ळे']
# ['खोट']
# ['खोशेचे']
# ['ख्यास्त']
# ['ख्यास्तीचें']
# ['गंभीर']
# ['गंभीरपणान']
# ['गच्छामि']
# ['गछामी']
# ['गजाल']
# ['गजाल']
# ['गजाल']
# ['गजाल']
# ['गजालीची']
# ['गडगंज']
# ['गडगड']
# ['गडगडाची']
# ['गणपती']
# ['गणपती']
# ['गणपती']
# ['गणपतीक']
# ['गत']
# ['गतीन']
# ['गरज']
# ['गरज']
# ['गरज']
# ['गरज']
# ['गरज']
# ['गरज']
# ['गरज']
# ['गरज']
# ['गरजेचें']
# ['गरिबीची']
# ['गरीब']
# ['गरीब']
# ['गर्देत']
# ['गांठली']
# ['गांधी']
# ['गांधींच्या']
# ['गांधीक']
# ['गांधीवादी']
# ['गांव']
# ['गांवांत']
# ['गांवांतले']
# ['गांवांनी']
# ['गाडे']
# ['गुंड्यावरी']
# ['गुजरात']
# ['गुठलावन']
# ['गुन्यांव']
# ['गुन्यांवकार']
# ['गुपूत']
# ['गुर्जर']
# ['गुळी']
# ['गूण']
# ['गृह']
# ['गृह']
# ['गृहमंत्री']
# ['गेले']
# ['गेले']
# ['गेलो']
# ['गेलो']
# ['गेलो']
# ['गेलो']
# ['गेल्यार']
# ['गेल्यार']
# ['गेल्ली']
# ['गेल्ली']
# ['गेल्लें']
# ['गेल्लो']
# ['गैरसमज']
# ['गोंय']
# ['गोंय']
# ['गोंय']
# ['गोंय']
# ['गोंय']
# ['गोंय']
# ['गोंय']
# ['गोंयकार']
# ['गोंयकार']
# ['गोंयकार']
# ['गोंयची']
# ['गोंया']
# ['गोंयांत']
# ['गोंयांत']
# ['गोंयांत']
# ['गोंयांतूय']
# ['गोंयांतूय']
# ['गोंयाचो']
# ['गोंयात']
# ['गोऱया']
# ['गोरो']
# ['घटकूय']
# ['घटकेक']
# ['घटना']
# ['घट्ट']
# ['घडचेच']
# ['घडणुकांचो']
# ['घडणुकेक']
# ['घडणुकेचो']
# ['घडणुको']
# ['घडणूक']
# ['घडपाक']
# ['घडपाक']
# ['घडयतना']
# ['घडयला']
# ['घडये']
# ['घडलां']
# ['घडलां']
# ['घडलां']
# ['घडल्यांत']
# ['घडल्यात']
# ['घडे']
# ['घडोवन']
# ['घडोवन']
# ['घरतात']
# ['घरा']
# ['घरा']
# ['घरांचेर']
# ['घरांत']
# ['घरांत']
# ['घरांत']
# ['घरांतले']
# ['घरांतूच']
# ['घरांब्यांचो']
# ['घरांय']
# ['घराबो']
# ['घराब्यांची']
# ['घराव्या']
# ['घांटरूय']
# ['घाल']
# ['घालपा']
# ['घालपाचे']
# ['घालपाचो']
# ['घालपाचो']
# ['घालपी']
# ['घाला']
# ['घाली']
# ['घालून']
# ['घालून']
# ['घालून']
# ['घालून']
# ['घाल्या']
# ['घाल्यात']
# ['घाल्लें']
# ['घाळपण']
# ['घाव']
# ['घावे']
# ['घुंवपाक']
# ['घुमट्यांतल्यो']
# ['घुमट्यो']
# ['घुस्पल्यात']
# ['घुस्पल्यात']
# ['घेतला']
# ['घेतली']
# ['घेतली']
# ['घेतली']
# ['घेतली']
# ['घेतले']
# ['घेतलें']
# ['घेतल्यात']
# ['घेतल्यानी']
# ['घेतात']
# ['घेतात']
# ['घेतिल्ली']
# ['घेतिल्ली']
# ['घेतिल्ले']
# ['घेतिल्लो']
# ['घेतिल्ल्या']
# ['घेतिल्ल्या']
# ['घेतिल्ल्या']
# ['घेवंक']
# ['घेवचो']
# ['घेवन']
# ['घेवन']
# ['घेवन']
# ['घेवन']
# ['घेवन']
# ['घेवन']
# ['घेवन']
# ['घेवनूच']
# ['घेवनूय']
# ['घेवप']
# ['घेवप']
# ['घेवपा']
# ['घेवपाक']
# ['घेवपाक']
# ['घेवपाक']
# ['घेवपाक']
# ['घेवपाची']
# ['घेवपाची']
# ['घेवपाची']
# ['घेवपाची']
# ['घेवपाचोय']
# ['घेवपाच्या']
# ['घोळ']
# ['घोळना']
# ['घोशणा']
# ['घोशणा']
# ['चंदिगढ']
# ['चंद्राचेर']
# ['चड']
# ['चड']
# ['चड']
# ['चड']
# ['चड']
# ['चड']
# ['चड']
# ['चड']
# ['चड']
# ['चड']
# ['चडप']
# ['चडशे']
# ['चडशें']
# ['चडश्यो']
# ['चडसो']
# ['चणे']
# ['चण्या']
# ['चरून']
# ['चर्चिलान']
# ['चर्चे']
# ['चर्चेत']
# ['चर्वण']
# ['चलत']
# ['चलतलें?']
# ['चलता']
# ['चलता']
# ['चलता']
# ['चलयला']
# ['चल्ला']
# ['चल्ल्या?']
# ['चल्ल्यात']
# ['चवकशी']
# ['चवकशी']
# ['चवकशी']
# ['चवथ']
# ['चवथ']
# ['चवथीची']
# ['चवथीचे']
# ['चवथीच्या']
# ['चवथीच्या']
# ['चाबकाच्या']
# ['चार']
# ['चारचवगांत']
# ['चाल']
# ['चालकांनी']
# ['चाली']
# ['चालींतल्यान']
# ['चालीक']
# ['चालीक']
# ['चालीरिती']
# ['चालू']
# ['चालू']
# ['चिंतन']
# ['चिंतन']
# ['चिंतन']
# ['चिंतन']
# ['चिंतन']
# ['चिड्डिलें']
# ['चिड्डून']
# ['चित्र']
# ['चिन्नां']
# ['चिपी']
# ['चिपी']
# ['चिपी']
# ['चिपी']
# ['चिपी']
# ['चिपीचें']
# ['चिपीचो']
# ['चिमटो']
# ['चीन']
# ['चुकीचे']
# ['चूक']
# ['चॅ']
# ['चॅनॅलाक']
# ['चेपण']
# ['चेपपाचो']
# ['चेऱयाचो']
# ['चेरो']
# ['चोंबे']
# ['चोंबो']
# ['चोरून']
# ['च्या']
# ['जग']
# ['जगयिल्ली']
# ['जतनाय']
# ['जनता']
# ['जनता']
# ['जनता']
# ['जनता']
# ['जनता']
# ['जनपथ']
# ['जनरल']
# ['जनरल']
# ['जपतना']
# ['जमना']
# ['जमनी']
# ['जमनीक']
# ['जमनीचेर']
# ['जमनीर']
# ['जमनीर']
# ['जमलींच']
# ['जमलें']
# ['जमात']
# ['जमातीचे']
# ['जमीन']
# ['जमीन']
# ['जमीन']
# ['जमीन']
# ['जयललिता']
# ['जर']
# ['जल्मा']
# ['जवड्यांत']
# ['जशीं']
# ['जसवंत']
# ['जसवंत']
# ['जसवंत']
# ['जसवंतसिंगाकतीय']
# ['जसवंतांचेय']
# ['जसवंताक']
# ['जसवंताक']
# ['जसवंताक']
# ['जसवंताचे']
# ['जांची']
# ['जांचे']
# ['जाका']
# ['जाका']
# ['जागी']
# ['जागे']
# ['जागे']
# ['जागो']
# ['जाग्यार']
# ['जाग्यार']
# ['जाच्या']
# ['जाण']
# ['जाण']
# ['जाणवता']
# ['जाणवले']
# ['जाणविकाय']
# ['जाणविकाय']
# ['जाणवूंक']
# ['जाणांक']
# ['जाणांक']
# ['जाणांचे']
# ['जाणांचो']
# ['जाणात']
# ['जाणीव']
# ['जाणीव']
# ['जाणूनबुजून']
# ['जात']
# ['जातकच']
# ['जातली']
# ['जातलीय']
# ['जातले']
# ['जातलें?']
# ['जातलो']
# ['जातलो']
# ['जातलो']
# ['जातल्यो']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जाता']
# ['जातात']
# ['जाताली']
# ['जानेवारी']
# ['जाप']
# ['जापसालदार']
# ['जापसालदारकी']
# ['जापसालदारकी']
# ['जापसालदारकी']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जाय']
# ['जायच']
# ['जायत']
# ['जायत']
# ['जायत']
# ['जायत']
# ['जायत']
# ['जायत']
# ['जायत']
# ['जायत्या']
# ['जायना']
# ['जायना']
# ['जायना']
# ['जायना']
# ['जाला']
# ['जाला']
# ['जाला']
# ['जाला']
# ['जालां']
# ['जालां']
# ['जालां']
# ['जाली']
# ['जाली']
# ['जालीं']
# ['जालीं']
# ['जाले']
# ['जाले']
# ['जाले']
# ['जालें']
# ['जालें']
# ['जालें']
# ['जालो']
# ['जालो']
# ['जालो']
# ['जालो']
# ['जालो']
# ['जालो']
# ['जालो']
# ['जालो']
# ['जालो']
# ['जाल्या']
# ['जाल्या']
# ['जाल्या']
# ['जाल्या']
# ['जाल्यांत']
# ['जाल्यात']
# ['जाल्यात']
# ['जाल्यात']
# ['जाल्यात']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यार']
# ['जाल्यारूच']
# ['जाल्ली']
# ['जाल्ली']
# ['जाल्ले']
# ['जाल्ले']
# ['जाल्ले']
# ['जाल्ले']
# ['जाल्ले']
# ['जाल्लें']
# ['जाल्लो']
# ['जाल्ल्या']
# ['जाल्ल्यान']
# ['जाल्ल्यानच']
# ['जाळवणदारांचो']
# ['जावं']
# ['जावं']
# ['जावंक']
# ['जावंक']
# ['जावंक']
# ['जावंक']
# ['जावची']
# ['जावची']
# ['जावची']
# ['जावची']
# ['जावचें']
# ['जावचेंना']
# ['जावचेच']
# ['जावचो']
# ['जावन']
# ['जावन']
# ['जावन']
# ['जावन']
# ['जावन']
# ['जावप']
# ['जावपा']
# ['जावपा']
# ['जावपाक']
# ['जावपाक']
# ['जावपाक']
# ['जावपाक']
# ['जावपाक']
# ['जावपाक']
# ['जावपाक']
# ['जावपाची']
# ['जावपाची']
# ['जावपाची']
# ['जावपाचीं']
# ['जावपाचीं']
# ['जावपी']
# ['जावपी']
# ['जावपूय']
# ['जाहीर']
# ['जाहीर']
# ['जाहीर']
# ['जाहीरपणान']
# ['जिणेंत']
# ['जिनस']
# ['जिनसांची']
# ['जिनसांचीं']
# ['जिनसांचीं']
# ['जिनसांच्या']
# ['जिनसाचें']
# ['जिना']
# ['जिनांची']
# ['जिनांची']
# ['जिनांचो']
# ['जिवां']
# ['जिवार']
# ['जिवेशीं']
# ['जी']
# ['जी']
# ['जी']
# ['जी-']
# ['जीव']
# ['जुलय']
# ['जुलय']
# ['जुलय']
# ['जुळोवन']
# ['जुवान']
# ['जूं']
# ['जे']
# ['जे']
# ['जे']
# ['जे']
# ['जे']
# ['जे']
# ['जे']
# ['जे']
# ['जे']
# ['जें']
# ['जें']
# ['जेटली']
# ['जेटलीक']
# ['जेटलीक']
# ['जेन्ना']
# ['जेन्ना']
# ['जॉन']
# ['जो']
# ['जो']
# ['जो']
# ['जो']
# ['जो']
# ['जो']
# ['जोड']
# ['जोडटले']
# ['जोडपी']
# ['जोडल्यात']
# ['जोडी']
# ['जोडीच्या']
# ['ज्ञान-विज्ञानाचीं']
# ['ज्या']
# ['ज्या']
# ['ज्या']
# ['ज्युस्त']
# ['ज्येश्ठ']
# ['ज्येश्ठ']
# ['ज्येश्ठ']
# ['ज्येश्ठ']
# ['ज्येश्ठ']
# ['झगडटा']
# ['झारखंड']
# ['झारखंडांत']
# ['झारखंडांत']
# ['झारखंडाचो']
# ['झुंडशायेची']
# ['झुजतना']
# ['झुजपाक']
# ['झुजपाक']
# ['झुजा']
# ['झुजाऱ्यावरी']
# ['झूज']
# ['टक्के']
# ['टक्कें']
# ['टक्को']
# ['टक्क्यां']
# ['टनाशिल्ले']
# ['टायम्स']
# ['टिका']
# ['टिळकाक']
# ['टॅक्सी']
# ['टॅक्सीचालकांनी']
# ['टोळयो']
# ['ठाकूर']
# ['ठाकूर']
# ['ठाणे']
# ['ठेकेदारी']
# ['ठेको']
# ['ठोकताळे']
# ['डाव']
# ['डाव']
# ['ढवळीकारा']
# ['ढवळीकाराचो']
# ['ढवळीकाराच्या']
# ['त']
# ['त']
# ['त']
# ['तंत्रात']
# ['तकली']
# ['तगयिल्ली']
# ['तजवीज']
# ['तटस्थ']
# ['तटस्थताय']
# ['तडजोड']
# ['तडजोड']
# ['तडजोडींतल्यान']
# ['तणाव']
# ['तत्वांचेर']
# ['तन']
# ['तपासपाची']
# ['तफावत']
# ['तमुचेच']
# ['तयार']
# ['तयार']
# ['तयार']
# ['तयार']
# ['तयार']
# ['तयार']
# ['तयारी']
# ['तयारी']
# ['तयारी']
# ['तयारी']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तर']
# ['तरणाटे']
# ['तरणाटे']
# ['तरणाट्या']
# ['तरणाट्यां']
# ['तरणाट्यांक']
# ['तरणाट्यांकूय']
# ['तरणाट्यांची']
# ['तरणाट्यांचे']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरी']
# ['तरीय']
# ['तरीय']
# ['तरेकवार']
# ['तरेचो']
# ['तरेन']
# ['तरेन']
# ['तरेन']
# ['तर्कशुद्धपणान']
# ['तले']
# ['तळाक']
# ['तशी']
# ['तशी']
# ['तशे']
# ['तशें']
# ['तशें']
# ['तशें']
# ['तशें']
# ['तशें']
# ['तशें']
# ['तशेंच']
# ['तशेंच']
# ['तशेंच']
# ['तशेंच']
# ['तसो']
# ['तसो']
# ['तांक']
# ['तांक']
# ['तांक']
# ['तांक']
# ['तांकां']
# ['तांकां']
# ['तांकां']
# ['तांकां']
# ['तांकां']
# ['तांकां']
# ['तांकां']
# ['तांची']
# ['तांची']
# ['तांची']
# ['तांची']
# ['तांची']
# ['तांची']
# ['तांचीय']
# ['तांचे']
# ['तांचे']
# ['तांचे']
# ['तांचे']
# ['तांचे']
# ['तांचे']
# ['तांचे']
# ['तांचे']
# ['तांचे']
# ['तांचें']
# ['तांचें']
# ['तांचें']
# ['तांचेय']
# ['तांचो']
# ['तांचो']
# ['तांचो']
# ['तांचो']
# ['तांचो']
# ['तांचो']
# ['तांच्या']
# ['तांच्या']
# ['तांच्या']
# ['तांच्या']
# ['तांच्या']
# ['तांच्या']
# ['तांच्यो']
# ['तांणी']
# ['तांणी']
# ['तांणी']
# ['तांणी']
# ['तांणी']
# ['तांणी']
# ['तांणी']
# ['तांणी']
# ['तांतूत']
# ['तांतूतले']
# ['तांतूतल्यो']
# ['तांदळांतल्या']
# ['ताकतिकेतूच']
# ['ताकतीक']
# ['ताकतीक']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताका']
# ['ताकाय']
# ['ताची']
# ['ताची']
# ['ताची']
# ['ताची']
# ['ताची']
# ['ताचे']
# ['ताचे']
# ['ताचे']
# ['ताचे']
# ['ताचे']
# ['ताचे']
# ['ताचे']
# ['ताचें']
# ['ताचें']
# ['ताचें']
# ['ताचें']
# ['ताचें']
# ['ताचें']
# ['ताचेय']
# ['ताचेर']
# ['ताचेरूच']
# ['ताचो']
# ['ताचो']
# ['ताचो']
# ['ताचोच']
# ['ताच्या']
# ['ताच्या']
# ['ताच्या']
# ['ताच्या']
# ['ताच्या']
# ['ताच्या']
# ['ताच्या']
# ['ताच्या']
# ['ताच्याच']
# ['ताणे']
# ['ताणे']
# ['ताणें']
# ['ताणें']
# ['ताणेबाणे']
# ['ताततिकेन']
# ['तातूंत']
# ['तातूंत']
# ['तातूंत']
# ['तातूंत']
# ['तातूंत']
# ['तातूंत']
# ['तातूंत']
# ['तातूंतलोच']
# ['तातूंतल्यान']
# ['तामीळनाडूच्या']
# ['तारखांचोय']
# ['तारणहार']
# ['तारतम्य']
# ['तारलेंना']
# ['तालार']
# ['तालीम']
# ['ताळमेळ']
# ['तिका']
# ['तिका']
# ['तिका']
# ['तिका']
# ['तिका']
# ['तिका']
# ['तिका']
# ['तिकेटी']
# ['तिची']
# ['तिचे']
# ['तिचे']
# ['तिचे']
# ['तिचेच']
# ['तिचेर']
# ['तिचै']
# ['तिचो']
# ['तिच्या']
# ['तिच्या']
# ['तिच्या']
# ['तिच्या']
# ['तिच्या']
# ['तिच्यो']
# ['तिणे']
# ['तिणे']
# ['तिणे']
# ['तितलीं']
# ['तितलोच']
# ['तिसरया']
# ['तिसऱयाचो']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['ती']
# ['तीं']
# ['तीन']
# ['तीन']
# ['तीन']
# ['तीन']
# ['तीन']
# ['तीर्थी']
# ['तुकाराम']
# ['तुकारामान']
# ['तुटली']
# ['तुबक']
# ['तुमी']
# ['तुळा']
# ['तुस्त']
# ['तूट']
# ['तूप']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['ते']
# ['तेँ']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तें']
# ['तेंकता']
# ['तेंकली']
# ['तेंकल्या']
# ['तेंको']
# ['तेंक्यार']
# ['तेंच']
# ['तेंप']
# ['तेंप']
# ['तेंय']
# ['तेंय']
# ['तेंय']
# ['तेकोवन']
# ['तेगशी']
# ['तेच']
# ['तेच']
# ['तेजोभंगाच्या']
# ['तेढ']
# ['तेढ']
# ['तेढीचें']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेन्ना']
# ['तेरा']
# ['तेल']
# ['तेवटेन']
# ['तेवटेन']
# ['तेवटेन']
# ['तैप']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तो']
# ['तोंड']
# ['तोंड']
# ['तोंडांत']
# ['तोंडार']
# ['तोंडों']
# ['तोखणाय']
# ['तोड']
# ['तोडप']
# ['तोडपाची']
# ['तोडार']
# ['तोरीची']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्या']
# ['त्याच']
# ['त्यो']
# ['त्रास']
# ['त्रास']
# ['त्रास']
# ['थंड']
# ['थंड']
# ['थंडसाणींत']
# ['थंय']
# ['थंय']
# ['थंय']
# ['थंय']
# ['थंयच']
# ['थंयच्या']
# ['थंयच्या']
# ['थंयच्या']
# ['थंयूय']
# ['थप्प्यो']
# ['थळांचो']
# ['थळावे']
# ['थळाव्या']
# ['थळाव्या']
# ['थळाव्या']
# ['थळाव्या']
# ['थळाव्या']
# ['थांट']
# ['थाकाय']
# ['थान']
# ['थाय']
# ['थारची']
# ['थारता']
# ['थारलां']
# ['थारायलां']
# ['थारायलां']
# ['थारायलां']
# ['थारावन']
# ['थारावपाक']
# ['थारावपाचो']
# ['थारावपी']
# ['थारावीक']
# ['थाव']
# ['थीर']
# ['थोंट्या']
# ['थोड्याच']
# ['दंगल']
# ['दंगली']
# ['दंत']
# ['दक्षिण']
# ['दडपशाय']
# ['दर']
# ['दरबारांत']
# ['दरबारी']
# ['दरेक']
# ['दरेकल्या']
# ['दरेका']
# ['दरेका']
# ['दरेका']
# ['दरेका']
# ['दरेके']
# ['दर्जो']
# ['दर्जो']
# ['दर्यात']
# ['दलाच्या']
# ['दळ']
# ['दळ']
# ['दळणवळणाक']
# ['दळदीर']
# ['दळाची']
# ['दवपाचो']
# ['दवरचेच']
# ['दवरता']
# ['दवरतात']
# ['दवरप']
# ['दवरपाचे']
# ['दवरले']
# ['दवरले']
# ['दवरल्या']
# ['दवरिल्ले']
# ['दवरीत']
# ['दवरून']
# ['दवरून']
# ['दवरून']
# ['दवरून']
# ['दश्टीकोणूय']
# ['दसून']
# ['दांत']
# ['दांत']
# ['दांत']
# ['दाखयत']
# ['दाखयत']
# ['दाखयतले']
# ['दाखयनात']
# ['दाखयले']
# ['दाखयलें']
# ['दाखोवची']
# ['दाखोवन']
# ['दाखोवनूय']
# ['दाखोवप']
# ['दाखोवपाची']
# ['दाखोवपाची']
# ['दाखोवपाचे']
# ['दाखोवपाचें']
# ['दाखोवपाचो']
# ['दाखोवपाचो']
# ['दाटल्या']
# ['दाटून']
# ['दातां']
# ['दाताचो']
# ['दाबोळी']
# ['दाबोळेचो']
# ['दाबोळेच्या']
# ['दाबोळेच्यान']
# ['दारांत']
# ['दालनां']
# ['दाळ']
# ['दाळी']
# ['दावो']
# ['दिकाभूल']
# ['दिगंबर']
# ['दिगंबर']
# ['दिगंबरबाब']
# ['दितना']
# ['दितलें?']
# ['दितलोच']
# ['दितल्याक']
# ['दिता']
# ['दिता']
# ['दितात']
# ['दितात']
# ['दिनात']
# ['दिमी']
# ['दिला']
# ['दिलां']
# ['दिलां']
# ['दिली']
# ['दिली']
# ['दिली']
# ['दिलो']
# ['दिल्या']
# ['दिल्या']
# ['दिल्या']
# ['दिल्या']
# ['दिल्या']
# ['दिल्यात']
# ['दिल्यो']
# ['दिल्ली']
# ['दिल्ली']
# ['दिल्ली']
# ['दिल्ली']
# ['दिल्लींत']
# ['दिल्लींत']
# ['दिल्लींत']
# ['दिल्लींत']
# ['दिल्लींत']
# ['दिल्लीक']
# ['दिल्लीचे']
# ['दिल्ले']
# ['दिल्ले']
# ['दिल्ल्या']
# ['दिवं']
# ['दिवं']
# ['दिवं']
# ['दिवंक']
# ['दिवंक']
# ['दिवची']
# ['दिवचीच']
# ['दिवचे']
# ['दिवचें']
# ['दिवन']
# ['दिवपा']
# ['दिवपाक']
# ['दिवपाक']
# ['दिवपाक']
# ['दिवपाक']
# ['दिवपाक']
# ['दिवपाची']
# ['दिवपाची']
# ['दिवपाचें']
# ['दिवपाचो']
# ['दिवपी']
# ['दिवराक']
# ['दिवाळे']
# ['दिवे']
# ['दिशा']
# ['दिशिल्ली']
# ['दिशिल्लें']
# ['दिश्टावो']
# ['दिश्टीकोण']
# ['दिस']
# ['दिसचेंय']
# ['दिसता']
# ['दिसता']
# ['दिसता']
# ['दिसता']
# ['दिसता']
# ['दिसतात']
# ['दिसतात']
# ['दिसतात']
# ['दिसना']
# ['दिसना']
# ['दिसना']
# ['दिसपाक']
# ['दिसपाक']
# ['दिसा']
# ['दिसा']
# ['दिसा']
# ['दिसांची']
# ['दिसान']
# ['दिसान']
# ['दिसूंक']
# ['दिसूंक']
# ['दीत']
# ['दीत']
# ['दीस']
# ['दीस']
# ['दीस']
# ['दीस']
# ['दीस']
# ['दीस']
# ['दीसपट्टे']
# ['दीसपट्ट्या']
# ['दुकळ']
# ['दुकळाची']
# ['दुकांनां']
# ['दुखवपाक']
# ['दुखवल्ल्या']
# ['दुखावल्यो']
# ['दुबाव']
# ['दुबाव']
# ['दुबाव']
# ['दुबाव']
# ['दुबाव']
# ['दुबाव']
# ['दुबाव']
# ['दुबाविताच्या']
# ['दुबावीत']
# ['दुर्मीळ']
# ['दुसऱयांक']
# ['दुसरे']
# ['दुसरेंच']
# ['दुसरेवटेन']
# ['दुसरो']
# ['दुस्वास']
# ['दूर']
# ['दृश्टिकोन']
# ['दृश्टीन']
# ['देंवच्यो']
# ['देंवनात']
# ['देंवप']
# ['देख']
# ['देख']
# ['देखुनूच']
# ['देखून']
# ['देखून']
# ['देखून']
# ['देखून']
# ['देखून']
# ['देखून']
# ['देखून']
# ['देड']
# ['देरेक']
# ['देव']
# ['देव']
# ['देव-धर्म']
# ['देवळां']
# ['देवळां']
# ['देवळांची']
# ['देवळांचीय']
# ['देवळांतल्यो']
# ['देवळांनी']
# ['देवांच्यो']
# ['देवाचे']
# ['देवै']
# ['देश']
# ['देश']
# ['देश']
# ['देश']
# ['देशां']
# ['देशांक']
# ['देशांत']
# ['देशांत']
# ['देशांत']
# ['देशांतल्या']
# ['देशांनी']
# ['देशाक']
# ['देशाक']
# ['देशाची']
# ['देशाची']
# ['देशाचे']
# ['देशाचे']
# ['दोग']
# ['दोगां']
# ['दोगांकय']
# ['दोगांय']
# ['दोन']
# ['दोन']
# ['दोन']
# ['दोन']
# ['दोन']
# ['दोन']
# ['दोन']
# ['दोन']
# ['दोन']
# ['दोना']
# ['दोनूय']
# ['दोरयांचेर']
# ['दोरयो']
# ['दोळ्यांक']
# ['दोळ्यांचेर']
# ['दौऱयांत']
# ['धडधड']
# ['धडधडपाक']
# ['धनान']
# ['धपको']
# ['धपक्यांतल्यान']
# ['धपक्यान']
# ['धमकावन']
# ['धमकी']
# ['धरपाक']
# ['धरपाक']
# ['धरपी']
# ['धरला']
# ['धरलीं']
# ['धरलो']
# ['धरिल्ले']
# ['धरून']
# ['धर्तेर']
# ['धर्म']
# ['धर्म']
# ['धर्म']
# ['धर्मग्रंथ']
# ['धर्मनिरपेक्ष']
# ['धर्मा']
# ['धर्मांच्या']
# ['धर्मांत']
# ['धर्मांनी']
# ['धर्माची']
# ['धर्माची']
# ['धर्माचे']
# ['धर्माचे']
# ['धर्माचे']
# ['धर्माचेर']
# ['धर्माचेर']
# ['धर्माच्या']
# ['धर्माच्या']
# ['धर्मीक']
# ['धर्मीक']
# ['धर्मीक']
# ['धर्मीक']
# ['धर्मीक']
# ['धर्मीक']
# ['धर्मीक']
# ['धर्मीक']
# ['धर्मीकताय']
# ['धा']
# ['धांपून']
# ['धांवडायतना']
# ['धांवडावन']
# ['धांवडावपाची']
# ['धांवडावपाचे']
# ['धाडटले']
# ['धाडला']
# ['धाडस']
# ['धाडस']
# ['धाडी']
# ['धाडीय']
# ['धाडून']
# ['धाडून']
# ['धार्मीक']
# ['धार्मीक']
# ['धुंवर']
# ['धुंवरेता']
# ['धुमशेणां']
# ['धुवपाची']
# ['धेंगां']
# ['धेवपाचें']
# ['धोंडा']
# ['धोको']
# ['धोरणी']
# ['धोलाचेर']
# ['नगराध्यक्षांनी']
# ['नगरीची']
# ['नजो']
# ['नजो']
# ['नजो']
# ['नदरकैदेंत']
# ['नदरेक']
# ['नदरेन']
# ['नमन']
# ['नरकासुर']
# ['नरकासुराचें']
# ['नरेंद्र']
# ['नळ']
# ['नवागतांक']
# ['नवी']
# ['नवी']
# ['नवे']
# ['नवो']
# ['नव्या']
# ['नव्या']
# ['नव्यान']
# ['नव्यान']
# ['नव्यान']
# ['नव्योच']
# ['नश्टचक्रांतल्यान']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना']
# ['ना?']
# ['ना?']
# ['ना?']
# ['नां']
# ['नांव']
# ['नांवां']
# ['नांवाच्या']
# ['नांवान']
# ['नांवान']
# ['नांवान']
# ['नांवान']
# ['नांवार']
# ['नाक']
# ['नाका']
# ['नाका']
# ['नाका']
# ['नागपूरांतल्या']
# ['नागरिकांच्यो']
# ['नागरिकाक']
# ['नागरी']
# ['नागरी']
# ['नागरी']
# ['नागरी']
# ['नाचतात']
# ['नाजूक']
# ['नाटक']
# ['नाट्यप्रयोग']
# ['नाडपी']
# ['नात']
# ['नात']
# ['नात']
# ['नात']
# ['नात']
# ['नात']
# ['नायक']
# ['नारायण']
# ['नारायण']
# ['नारायण']
# ['नाल्ल']
# ['नाळ']
# ['नाळ']
# ['नाव']
# ['नाशिल्ली']
# ['नाशिल्ले']
# ['नाशिल्ले']
# ['नाशिल्ले']
# ['नाशिल्लें']
# ['नाशिल्लो']
# ['नाशिल्लो']
# ['नाशिल्लो']
# ['नाशिल्ल्याकय']
# ['नाशिल्ल्याचे']
# ['नाशिल्ल्यान']
# ['नासता']
# ['नासलें']
# ['निंबून']
# ['निंबून']
# ['निखळपाची']
# ['नितळसाणीचो']
# ['निधर्मी']
# ['निमंत्रितांक']
# ['निमतान']
# ['निमतान']
# ['निमतान']
# ['निमित्त']
# ['निमित्त']
# ['नियंत्रण']
# ['नियंत्रण']
# ['नियंत्रण']
# ['निर्णय']
# ['निर्णय']
# ['निर्णय']
# ['निर्णय']
# ['निर्बंध']
# ['निर्माण']
# ['निर्माण']
# ['निर्माण']
# ['निर्मिती']
# ['निर्लज्जपणान']
# ['निवास']
# ['निवृत्ती']
# ['निशेध']
# ['निशेध']
# ['निश्चीत']
# ['निश्ठा']
# ['निश्पाप']
# ['निश्प्रभ']
# ['निस्मद्रवी']
# ['नू']
# ['ने']
# ['नेट']
# ['नेटान']
# ['नेटान']
# ['नेम']
# ['नेम']
# ['नेमकें']
# ['नेमणूक']
# ['नेमणूक']
# ['नेमले']
# ['नेमां']
# ['नेमून']
# ['नेहरू']
# ['नो']
# ['नोकर']
# ['नोकरी']
# ['नोटीस']
# ['नोबेल']
# ['न्याय']
# ['न्यायालयान']
# ['न्हंयेंतल्यान']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय']
# ['न्हय?']
# ['न्हय?']
# ['न्हयकारपाक']
# ['न्हिदले']
# ['पंगड']
# ['पंगड']
# ['पंगडांतल्या']
# ['पंगडान']
# ['पंचनामो']
# ['पंथ']
# ['पक्ष']
# ['पक्ष']
# ['पक्ष']
# ['पक्ष']
# ['पक्ष']
# ['पक्ष']
# ['पक्षा']
# ['पक्षा']
# ['पक्षांत']
# ['पक्षांतलीं']
# ['पक्षांतल्या']
# ['पक्षांतल्यान']
# ['पक्षांतल्यान']
# ['पक्षाक']
# ['पक्षाक']
# ['पक्षाक']
# ['पक्षाक']
# ['पक्षाक']
# ['पक्षाक']
# ['पक्षाची']
# ['पक्षाची']
# ['पक्षाची']
# ['पक्षाची']
# ['पक्षाची']
# ['पक्षाची']
# ['पक्षाचे']
# ['पक्षाचे']
# ['पक्षाचे']
# ['पक्षाचे']
# ['पक्षाचे']
# ['पक्षाचो']
# ['पक्षाच्या']
# ['पक्षाच्या']
# ['पक्षाच्या']
# ['पक्षाच्या']
# ['पक्षाच्या']
# ['पक्षाध्यक्ष']
# ['पक्षान']
# ['पगार']
# ['पगार']
# ['पगारांक']
# ['पगाराचेर']
# ['पचन']
# ['पटनाशिल्ले']
# ['पटींनी']
# ['पट्टो']
# ['पडचें']
# ['पडटकच']
# ['पडटली']
# ['पडटले']
# ['पडटलें']
# ['पडटलें']
# ['पडटलें']
# ['पडटलें']
# ['पडटलें']
# ['पडटलो']
# ['पडटा']
# ['पडटा']
# ['पडटा']
# ['पडटा']
# ['पडटा']
# ['पडटात']
# ['पडटात']
# ['पडत']
# ['पडत']
# ['पडना']
# ['पडपाक']
# ['पडपाक']
# ['पडले']
# ['पडलें']
# ['पडलें']
# ['पडल्या']
# ['पडसाद']
# ['पडसाद']
# ['पडिल्ली']
# ['पडूंक']
# ['पडून']
# ['पडूनच']
# ['पणजी']
# ['पणजे']
# ['पती']
# ['पत्रकार']
# ['पत्रकारांनी']
# ['पद']
# ['पदचिन्नां']
# ['पदराची']
# ['पदाचेरूय']
# ['पद्दत']
# ['पद्दत']
# ['पद्दतीन']
# ['पनवेलांत']
# ['पन्नास']
# ['पयर']
# ['पयर']
# ['पयली']
# ['पयलीं']
# ['पयलीं']
# ['पयलीं']
# ['पयलीं']
# ['पयलीं']
# ['पयलीं']
# ['पयलीं']
# ['पयलीं']
# ['पयलीं']
# ['पयलींच']
# ['पयलींची']
# ['पयले']
# ['पयल्या']
# ['पयल्या']
# ['पयशांचेर']
# ['पयशे']
# ['पयशें']
# ['पयशेकारांचे']
# ['पयस']
# ['पयस']
# ['पयस']
# ['पयस']
# ['पयसुल्ल्या']
# ['पयसो']
# ['पयसो']
# ['पयसो']
# ['परंपरा']
# ['परंपरेचे']
# ['परगटायले']
# ['परत']
# ['परत']
# ['परत']
# ['परत']
# ['परत']
# ['परत']
# ['परत']
# ['परत']
# ['परतलेय']
# ['परब']
# ['परब']
# ['परबे']
# ['परवडटलो']
# ['परस']
# ['परस']
# ['परस']
# ['परस']
# ['परस']
# ['परस्पर']
# ['पराभव']
# ['पराभव']
# ['पराभवा']
# ['पराभवाची']
# ['पराभवाचेरूय']
# ['परावलंबित्त्वाची']
# ['परिवारा']
# ['परिवाराक']
# ['परिशदेचें']
# ['परिस्थिती']
# ['परिस्थिती']
# ['परिस्थितींत']
# ['परिस्थितींत']
# ['परिस्थितीचें']
# ['परिस्थितीच्या']
# ['परी']
# ['पर्याय']
# ['पर्यायान']
# ['पर्यायान']
# ['पर्यावरण']
# ['पर्वरी']
# ['पळयत']
# ['पळयत']
# ['पळयल्यार']
# ['पळयल्यार']
# ['पळयल्यार']
# ['पळोवंक']
# ['पळोवन']
# ['पळोवन']
# ['पळोवन']
# ['पळोवन']
# ['पळोवपा']
# ['पळोवपाक']
# ['पळोवपाक']
# ['पळोवपाक']
# ['पळोवया']
# ['पवराक']
# ['पवार']
# ['पवारांक']
# ['पवारान']
# ['पसून']
# ['पसून']
# ['पांखां']
# ['पांच']
# ['पांच']
# ['पांच']
# ['पांच']
# ['पांच']
# ['पांच']
# ['पांजऱयांत']
# ['पांजऱयांत']
# ['पांडुरंग']
# ['पांय']
# ['पांय']
# ['पांय']
# ['पांयाचेर']
# ['पांवड्यार']
# ['पांवड्यार']
# ['पांवूंक']
# ['पाकिस्तानाची']
# ['पाकिस्तानाचे']
# ['पाखां']
# ['पाचारतात']
# ['पाचारिना']
# ['पाचो']
# ['पाटील']
# ['पाडीं']
# ['पाणी']
# ['पातळावपाचें']
# ['पाताळ']
# ['पानवळ']
# ['पालन']
# ['पावल']
# ['पावला']
# ['पावलां']
# ['पावलां']
# ['पावलार']
# ['पावले']
# ['पावले']
# ['पावले']
# ['पावलो']
# ['पावलो']
# ['पावलो']
# ['पावल्या']
# ['पावल्यात']
# ['पावल्यात']
# ['पावस']
# ['पावसाचेर']
# ['पावसान']
# ['पावोवपाचो']
# ['पिकां']
# ['पिकास']
# ['पिराय']
# ['पिरायेच']
# ['पिरायेचो']
# ['पिरोयेच्या']
# ['पिळवणूक']
# ['पिळिल्ल्या']
# ['पिसवता']
# ['पुजाय']
# ['पुनरवृत्ती']
# ['पुनरावृत्ती']
# ['पुनरावृत्ती']
# ['पुरतेंच']
# ['पुरयत']
# ['पुरवणे']
# ['पुरवणेचो']
# ['पुरस्कार']
# ['पुराय']
# ['पुराय']
# ['पुराय']
# ['पुराय']
# ['पुराय']
# ['पुरून']
# ['पुरो']
# ['पुर्वेतिहास']
# ['पुलिसांक']
# ['पुलिसांक']
# ['पुलिसांकडेन']
# ['पुलीस']
# ['पुलीस']
# ['पुस्तकां']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पूण']
# ['पेंगट']
# ['पेंवन']
# ['पेट्टा']
# ['पेडणेंची']
# ['पेडणेंचे']
# ['पेडणेंच्या']
# ['पेडणेकाराचें']
# ['पेडण्यान']
# ['पेलना']
# ['पेल्यांतल्या']
# ['पोंदा']
# ['पोखरता']
# ['पोखरतात']
# ['पोट']
# ['पोटली']
# ['पोटा']
# ['पोटाक']
# ['पोटाक']
# ['पोरकटपण']
# ['पोरणे']
# ['पोरण्या']
# ['पोरण्या']
# ['पोरूं']
# ['पोरूं']
# ['प्रकरण']
# ['प्रकरण']
# ['प्रकरणां']
# ['प्रकरणांचो']
# ['प्रकल्प']
# ['प्रकल्प']
# ['प्रकल्पाचेर']
# ['प्रकार']
# ['प्रकार']
# ['प्रकार']
# ['प्रकारांक']
# ['प्रकाश']
# ['प्रक्रिया']
# ['प्रक्रियेतल्यानूय']
# ['प्रगत']
# ['प्रचार']
# ['प्रचार']
# ['प्रचाराचें']
# ['प्रजा']
# ['प्रणेतो']
# ['प्रतिक्रिया']
# ['प्रतिमा']
# ['प्रतिमेच्यो']
# ['प्रतिवाद']
# ['प्रतिशह']
# ['प्रतिश्ठेचो']
# ['प्रतिसाद']
# ['प्रत्यक्षांत']
# ['प्रदर्शनाक']
# ['प्रदेशांतलो']
# ['प्रधानमंत्री']
# ['प्रधानमंत्र्यां']
# ['प्रबोधन']
# ['प्रभारी']
# ['प्रभाव']
# ['प्रभावा']
# ['प्रभावी']
# ['प्रमाण']
# ['प्रमाण']
# ['प्रमाण']
# ['प्रमाण']
# ['प्रमाण']
# ['प्रमाण']
# ['प्रयोजन']
# ['प्रवचनां']
# ['प्रवासाची']
# ['प्रवाहाची']
# ['प्रवेश']
# ['प्रशस्तीच']
# ['प्रसाद']
# ['प्रसादा']
# ['प्रसिद्धी']
# ['प्रस्ताव']
# ['प्रस्ताव']
# ['प्रस्थ']
# ['प्रस्न']
# ['प्रस्न']
# ['प्रस्न']
# ['प्रस्न']
# ['प्रस्न']
# ['प्रस्न']
# ['प्रस्न']
# ['प्रस्नान']
# ['प्रहसन']
# ['प्रायश्चित']
# ['प्रायश्चिताचे']
# ['फकत']
# ['फकत']
# ['फकत']
# ['फकत']
# ['फकांडां']
# ['फटयल्यात']
# ['फटवना']
# ['फटोवं']
# ['फसपाचो']
# ['फसलो']
# ['फाट']
# ['फाटभुंयेर']
# ['फाटभुंयेर']
# ['फाटभूंय']
# ['फाटभूंय']
# ['फाटलीं']
# ['फाटलीं']
# ['फाटले']
# ['फाटलें']
# ['फाटलो']
# ['फाटल्या']
# ['फाटल्या']
# ['फाटल्या']
# ['फाटल्यान']
# ['फाटल्यान']
# ['फाटल्यान']
# ['फाटल्यान']
# ['फाटल्यान']
# ['फाटल्य़ान']
# ['फाटीं']
# ['फाटीं']
# ['फाटीं']
# ['फाटीचो']
# ['फाफुडपाचो']
# ['फायदो']
# ['फायदो']
# ['फारान']
# ['फाल्यां']
# ['फाल्यां']
# ['फावट']
# ['फावट']
# ['फावट']
# ['फावट']
# ['फावट']
# ['फावों']
# ['फावोना']
# ['फास्केंत']
# ['फुकट']
# ['फुगिल्लीं']
# ['फुटलां']
# ['फुडऱयांचीं']
# ['फुडली']
# ['फुडल्या']
# ['फुडल्या']
# ['फुडाकार']
# ['फुडारपण']
# ['फुडारपण']
# ['फुडारपणांत']
# ['फुडारपणाचेर']
# ['फुडारपणान']
# ['फुडाऱयां']
# ['फुडाऱयां']
# ['फुडाऱयांक']
# ['फुडाऱयांक']
# ['फुडाऱयांक']
# ['फुडाऱयांक']
# ['फुडाऱयांची']
# ['फुडाऱयांचे']
# ['फुडाऱयांचो']
# ['फुडाऱयांच्या']
# ['फुडाऱयांच्या']
# ['फुडाऱयांच्यो']
# ['फुडाऱयांतले']
# ['फुडाऱयांनी']
# ['फुडाऱयाक']
# ['फुडाऱयाचे']
# ['फुडारा']
# ['फुडारी']
# ['फुडारी']
# ['फुडारी']
# ['फुडारी']
# ['फुडारी']
# ['फुडारी']
# ['फुडारी']
# ['फुडारीय']
# ['फुडार्यां']
# ['फुडें']
# ['फुडें']
# ['फुरसद']
# ['फुलिल्ली']
# ['फुस्स']
# ['फूक']
# ['फोडपाचे']
# ['फोडपाचे']
# ['फोडपाच्यो']
# ['फोडप्यांक']
# ['फोडल्यो']
# ['फोडून']
# ['फोन']
# ['फोनांतल्यान']
# ['फोलपण']
# ['फ्रान्सान']
# ['फ्लॅट']
# ['बंगलें']
# ['बंद']
# ['बंदखण']
# ['बंदखण']
# ['बंदखणींत']
# ['बंदखणींत']
# ['बंदखणीची']
# ['बंदी']
# ['बंदी']
# ['बगर']
# ['बगर']
# ['बगर']
# ['बगर']
# ['बगर']
# ['बगर']
# ['बडी']
# ['बदनाम']
# ['बदल']
# ['बदल']
# ['बदला']
# ['बदलिल्ली']
# ['बऱयाचें']
# ['बरी']
# ['बरे']
# ['बरें']
# ['बरें']
# ['बरें']
# ['बरो']
# ['बरोच']
# ['बरोच']
# ['बरोच']
# ['बर्माची']
# ['बऱ्याच']
# ['बळगे']
# ['बळग्यार']
# ['बळार']
# ['बळिश्ट']
# ['बळी']
# ['बसका']
# ['बसका']
# ['बसकेंत']
# ['बसकेंत']
# ['बसकेंतले']
# ['बसकेक']
# ['बसकेचे']
# ['बसकेच्या']
# ['बसकेपयलीं']
# ['बसतली']
# ['बसतलो']
# ['बसतलो']
# ['बसतलो']
# ['बसपा']
# ['बसयतना']
# ['बसयली']
# ['बसलो']
# ['बसलो']
# ['बसल्या']
# ['बसल्यात']
# ['बसल्यात']
# ['बसोवन']
# ['बसोवपाचो']
# ['बहिरा']
# ['बाँम्बस्फोट']
# ['बांडवलांचें']
# ['बांदता']
# ['बांदपाक']
# ['बांदलां']
# ['बांदावळ']
# ['बांदीत']
# ['बांदून']
# ['बागवतात']
# ['बाब']
# ['बाबडो']
# ['बाबतींत']
# ['बाबतींत']
# ['बाबतींत']
# ['बाबरी']
# ['बाबा']
# ['बाबू']
# ['बाबू']
# ['बायजी']
# ['बायोकॉनच्या']
# ['बारकायेन']
# ['बारामती']
# ['बारीकसारीक']
# ['बालहट्ट']
# ['बाळगप']
# ['बाळगीत']
# ['बाळगुवप']
# ['बाळगून']
# ['बावलीं']
# ['बाह्म']
# ['बिगर']
# ['बिहाराचो']
# ['बिहारी']
# ['बिहारी']
# ['बी']
# ['बी']
# ['बी']
# ['बुन्याद']
# ['बुन्यादीचो']
# ['बुरखो']
# ['बुवा']
# ['बॅरिस्टर']
# ['बें']
# ['बेकायदा']
# ['बेकायदेशीर']
# ['बेकायदेशीर']
# ['बेकारी']
# ['बेत']
# ['बेस']
# ['बेस']
# ['बॉम्बस्फोट']
# ['बॉम्बस्फोट']
# ['बॉम्बस्फोटान']
# ['बोटांमोडपाक']
# ['बोफोर्साक']
# ['बोवाळ']
# ['ब्रह्मदेश']
# ['ब्रिटन']
# ['ब्रिटिशांची']
# ['भंय']
# ['भंयाक']
# ['भंयान']
# ['भंयानूच']
# ['भक्तांक']
# ['भडक']
# ['भडकावपाचे']
# ['भड्डटा']
# ['भड्डटात']
# ['भर']
# ['भर']
# ['भरतली']
# ['भरले']
# ['भरिल्लो']
# ['भरून']
# ['भलायकी']
# ['भवनाचेर']
# ['भशेन']
# ['भांगर']
# ['भांडवल']
# ['भाग']
# ['भागवत']
# ['भागवत']
# ['भागवतांचे']
# ['भागवतान']
# ['भागवतान']
# ['भागोवपी']
# ['भाग्य']
# ['भाजपा']
# ['भाजपा']
# ['भाजपा']
# ['भाजपा']
# ['भाजपांत']
# ['भाजपाक']
# ['भाजपाक']
# ['भाजपाक']
# ['भाजपाचे']
# ['भाजपाचे']
# ['भाजपाचे']
# ['भाजपाचे']
# ['भाजपाचेंच']
# ['भाजपाचो']
# ['भाजपाच्या']
# ['भाजपाच्या']
# ['भाजपान']
# ['भाजपान']
# ['भाजपान']
# ['भाजपाय']
# ['भाजपाल्या']
# ['भाजापाची']
# ['भान']
# ['भान']
# ['भानगगडींत']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायर']
# ['भायरे']
# ['भायलो']
# ['भारत']
# ['भारत']
# ['भारत']
# ['भारतवर्ष']
# ['भारता']
# ['भारतांत']
# ['भारतांत']
# ['भारताक']
# ['भारताक']
# ['भारताचे']
# ['भारताचो']
# ['भारताचोच']
# ['भारताच्या']
# ['भारतान']
# ['भारतीय']
# ['भारतीय']
# ['भारतीय']
# ['भारतीय']
# ['भारतीय']
# ['भावना']
# ['भावना']
# ['भावनांक']
# ['भाशणाच्या']
# ['भाशा']
# ['भाशेन']
# ['भास']
# ['भासतली']
# ['भासाभास']
# ['भासाभास']
# ['भासाभासेचो']
# ['भिजत']
# ['भितर']
# ['भितर']
# ['भितरली']
# ['भितरल्यान']
# ['भितरल्यान']
# ['भिरांत']
# ['भुमीपुजन']
# ['भुमीपुजन']
# ['भुमीपुजन']
# ['भुर्दड']
# ['भूंय']
# ['भूक']
# ['भेंडूच']
# ['भेकडावपाचें']
# ['भेटयलां']
# ['भेडां']
# ['भेद']
# ['भैरोसिंग']
# ['भोंवडावपी']
# ['भोगतात']
# ['भोगलें']
# ['भोव']
# ['भोव']
# ['भोवतेक']
# ['भौशीक']
# ['भौशीक']
# ['भौशीक']
# ['भौसाक']
# ['भ्रश्टाचार']
# ['मंगळा']
# ['मंडळी']
# ['मंडाले']
# ['मंत्रालयाचेर']
# ['मंत्रालयाच्या']
# ['मंत्रालयान']
# ['मंत्रिमंडळ']
# ['मंत्रिमंडळांत']
# ['मंत्रिमंडळांत']
# ['मंत्रिमंडळांतले']
# ['मंत्रिमंडळाक']
# ['मंत्रिमंडळात']
# ['मंत्री']
# ['मंत्री']
# ['मंत्री']
# ['मंत्री']
# ['मंत्री']
# ['मंत्री']
# ['मंत्रीपदाचो']
# ['मंत्रीपदाचो']
# ['मंत्र्याक']
# ['मंत्र्याक']
# ['मंत्र्यान']
# ['मंदिर']
# ['मंदीची']
# ['मगो']
# ['मजगतच्या']
# ['मजतीक']
# ['मजल']
# ['मजा']
# ['मझुमदार']
# ['मडकयकाराक']
# ['मडगांव']
# ['मडगांव']
# ['मडगांवा']
# ['मडगांवां']
# ['मडगांवांत']
# ['मडगांवातल्या']
# ['मडवळाच्या']
# ['मत']
# ['मतदारसंघ']
# ['मतभेद']
# ['मतींत']
# ['मतींत']
# ['मत्ताकांक्षा']
# ['मदली']
# ['मदले']
# ['मदलो']
# ['मदल्या']
# ['मदीं']
# ['मध्य']
# ['मध्ययुगांत']
# ['मध्ययुगीन']
# ['मन']
# ['मन']
# ['मनमोहन']
# ['मनमोहनान']
# ['मनशांक']
# ['मनशांक']
# ['मनशांची']
# ['मनशांचें']
# ['मनशांचो']
# ['मनशांनी']
# ['मनशाक']
# ['मनशाचें']
# ['मनशाचो']
# ['मनशाच्या']
# ['मनांत']
# ['मनांतलीं']
# ['मनीस']
# ['मनीस']
# ['मनीस']
# ['मनीस']
# ['मनीस']
# ['मनीस']
# ['मनीस']
# ['मनीस']
# ['मनोवृत्तीच्या']
# ['मरूंक']
# ['मर्दीं']
# ['मर्यादा']
# ['मर्यादा']
# ['मर्यादीत']
# ['मलमपट्टी']
# ['मळबाक']
# ['मळा']
# ['मळार']
# ['मशिदीच्या']
# ['महत्वांकांक्षी']
# ['महत्वाकांक्षा']
# ['महसूल']
# ['महापलिकेची']
# ['महामंडळ']
# ['महाराष्ट्र']
# ['महाराष्ट्र']
# ['महाराष्ट्रांत']
# ['महाराष्ट्राचे']
# ['महासत्ता']
# ['मा']
# ['मागणी']
# ['मागणी']
# ['मागलो']
# ['मागल्या']
# ['मागास']
# ['मागीर']
# ['माचयेर']
# ['माड्डिल्लेय']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मात']
# ['मातशें']
# ['मात्सो']
# ['माथ्यावयलो']
# ['मान']
# ['मान']
# ['मान']
# ['मानतात']
# ['मानपाच्या']
# ['मानवता']
# ['मानसपूत']
# ['माने']
# ['मान्य']
# ['मान्यताय']
# ['मान्यताय']
# ['मापां']
# ['मायावती']
# ['मारप']
# ['मार-बडय']
# ['मारिल्ली']
# ['मारीत']
# ['मारीत']
# ['मारून']
# ['मारून']
# ['मार्केट']
# ['मार्ग']
# ['मार्ग']
# ['मार्ग']
# ['मार्ग']
# ['मार्गस्थ']
# ['मार्गा']
# ['मार्गांनी']
# ['मार्शल']
# ['माल']
# ['मालगोंडा']
# ['मालेगांवांत']
# ['मिटर']
# ['मितव्यय']
# ['मिनटां']
# ['मिमांसा']
# ['मिरयत']
# ['मिरयत']
# ['मिरवणूक']
# ['मिरामार']
# ['मुंबय']
# ['मुक्त']
# ['मुक्त']
# ['मुखयमंत्र्यांचे']
# ['मुखवटो']
# ['मुखवटो']
# ['मुखा']
# ['मुखामळ']
# ['मुखामळा']
# ['मुखार']
# ['मुखार']
# ['मुखार']
# ['मुखार']
# ['मुखार']
# ['मुखार']
# ['मुखारय']
# ['मुखेली']
# ['मुख्यमंत्री']
# ['मुख्यमंत्री']
# ['मुख्यमंत्री']
# ['मुख्यमंत्री']
# ['मुख्यमंत्री']
# ['मुख्यमंत्री']
# ['मुख्यमंत्री']
# ['मुख्यमंत्रीपदाचें']
# ['मुख्यमंत्र्यांची']
# ['मुख्यमंत्र्यांचे']
# ['मुख्यमंत्र्यांचे']
# ['मुख्यमंत्र्यांचो']
# ['मुख्यमंत्र्याक']
# ['मुख्यमंत्र्यान']
# ['मुख्यालयांत']
# ['मुगांगांठीं']
# ['मुघल']
# ['मुदलयांत']
# ['मुर्ती']
# ['मुर्ती']
# ['मुर्ती']
# ['मुर्ती']
# ['मुलाखती']
# ['मुलाखातीच्या']
# ['मुल्ला-मौलवींच्या']
# ['मुळाचेरूच']
# ['मुळावे']
# ['मुव्हमँट']
# ['मुस्लिम']
# ['मूग']
# ['मूळ']
# ['मे']
# ['मेकळीक']
# ['मेकळे']
# ['मेजीत']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेन']
# ['मेरेनचो']
# ['मेरेनच्या']
# ['मेळची']
# ['मेळचो']
# ['मेळचोना']
# ['मेळचोना']
# ['मेळटलें']
# ['मेळटा']
# ['मेळटा']
# ['मेळटात']
# ['मेळटाले']
# ['मेळत']
# ['मेळना']
# ['मेळना']
# ['मेळनात']
# ['मेळनात']
# ['मेळनात']
# ['मेळपाक']
# ['मेळपाक']
# ['मेळिल्ले']
# ['मेळिल्ले']
# ['मेळूंक']
# ['मेळूंक']
# ['मेळ्ळा']
# ['मेळ्ळां']
# ['मेळ्ळी']
# ['मेळ्ळे']
# ['मेळ्ळे']
# ['मेळ्ळें']
# ['मेळ्ळो']
# ['मेळ्ळो']
# ['मेळ्ळ्या']
# ['मेळ्ळ्यां']
# ['मोग']
# ['मोटवे']
# ['मोडचे']
# ['मोडणाक']
# ['मोडपी']
# ['मोडप्यान']
# ['मोडा']
# ['मोडावरी']
# ['मोद']
# ['मोदी']
# ['मोदी']
# ['मोपा']
# ['मोपा']
# ['मोपा']
# ['मोपा']
# ['मोपा-']
# ['मोपा-']
# ['मोपाक']
# ['मोपाचे']
# ['मोपाचें']
# ['मोपाचेय']
# ['मोपाचेर']
# ['मोपाचो']
# ['मोपाच्या']
# ['मोबायल']
# ['मोरया']
# ['मोरया']
# ['मोरयाकांय']
# ['मोल']
# ['मोल']
# ['मोलवाड']
# ['मोलां']
# ['मोलां']
# ['मोलां']
# ['मोलांचेर']
# ['मोलांत']
# ['मोलांतली']
# ['मोह']
# ['मोहन']
# ['मोहन']
# ['मोहम्मद']
# ['म्यानमार']
# ['म्यानमार']
# ['म्यानमारा']
# ['म्यानमारांत']
# ['म्यानमारांतले']
# ['म्यानमाराची']
# ['म्यानमाराचे']
# ['म्यानमाराचे']
# ['म्यानमाराचेर']
# ['म्यानमाराच्या']
# ['म्यानमाराच्य़ा']
# ['म्यानमारूय']
# ['म्हण']
# ['म्हणचे']
# ['म्हणचे']
# ['म्हणचे']
# ['म्हणचे']
# ['म्हणचे']
# ['म्हणचे']
# ['म्हणचे']
# ['म्हणचें']
# ['म्हणटकूच']
# ['म्हणटा']
# ['म्हणटा']
# ['म्हणटा']
# ['म्हणटात']
# ['म्हणटात']
# ['म्हणटात']
# ['म्हणटात']
# ['म्हणटात']
# ['म्हणटात']
# ['म्हणटात']
# ['म्हणत']
# ['म्हणनात']
# ['म्हणपाक']
# ['म्हणपाचे']
# ['म्हणपाचे']
# ['म्हणपाचें']
# ['म्हणपाचें']
# ['म्हणपाचें']
# ['म्हणपाचें']
# ['म्हणपाचें']
# ['म्हणपाचो']
# ['म्हणपी']
# ['म्हणलें']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणल्यार']
# ['म्हणसर']
# ['म्हणूं']
# ['म्हत्व']
# ['म्हत्व']
# ['म्हत्वाचे']
# ['म्हत्वाचें']
# ['म्हत्वाचो']
# ['म्हत्वाचो']
# ['म्हयने']
# ['म्हयने']
# ['म्हयन्यांनी']
# ['म्हयन्यांभितर']
# ['म्हयन्याची']
# ['म्हायती']
# ['म्हायती']
# ['म्हायती']
# ['म्हायती']
# ['म्हायतीच्या']
# ['म्हारग']
# ['म्हारग']
# ['म्हारगाय']
# ['म्हारगाय']
# ['म्हारगायूय']
# ['म्हारगायेचो']
# ['म्हारगायेचो']
# ['म्हारगायेच्या']
# ['म्हारगायेन']
# ['म्हालगड्यांक']
# ['म्हुर्ताक']
# ['म्हुर्ताचेर']
# ['म्हुर्तार']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूण']
# ['म्हूर्त']
# ['म्हैसकरान']
# ['यंत्रणेक']
# ['यंत्रणेक']
# ['यच्नांत']
# ['यत्न']
# ['यत्न']
# ['यत्न']
# ['यत्न']
# ['यत्न']
# ['यत्न']
# ['यत्नांक']
# ['यत्नांचेर']
# ['यत्नांत']
# ['यवतमाळ']
# ['याद']
# ['यु']
# ['युतींतले']
# ['युतीचें']
# ['युरोपियन']
# ['युरोपी']
# ['यॅट']
# ['येणावळ']
# ['येतकच']
# ['येतली']
# ['येतली']
# ['येतले']
# ['येतलेंच']
# ['येतलो']
# ['येता']
# ['येता']
# ['येता']
# ['येता']
# ['येता']
# ['येता?']
# ['येतात']
# ['येना']
# ['येना']
# ['येरादारी']
# ['येरादारी']
# ['येरादारी']
# ['येवंक']
# ['येवकार']
# ['येवकार']
# ['येवची']
# ['येवचोना']
# ['येवन']
# ['येवन']
# ['येवन']
# ['येवन']
# ['येवपाक']
# ['येवपाक']
# ['येवपाक']
# ['येवपाची']
# ['येस']
# ['येस']
# ['योगेश']
# ['रंगतलो']
# ['रंगूनांत']
# ['रकाद']
# ['रक्षक']
# ['रक्षक']
# ['रगतांतूच']
# ['रगताक']
# ['रजपुतांनी']
# ['रजपूत']
# ['रथ']
# ['रथाक']
# ['रद्द']
# ['रवीबाब']
# ['रसत्याचे']
# ['रस्तो']
# ['रस्त्याचेर']
# ['रस्त्यावयलीं']
# ['रा']
# ['रा']
# ['राखण']
# ['राखण']
# ['राखण']
# ['राखणेक']
# ['राखतलो']
# ['राखपाक']
# ['राखीत']
# ['राज']
# ['राजकारण']
# ['राजकारण']
# ['राजकारण']
# ['राजकारण']
# ['राजकारण']
# ['राजकारणा']
# ['राजकारणा']
# ['राजकारणांत']
# ['राजकारणांत']
# ['राजकारणांत']
# ['राजकारणांतले']
# ['राजकारणाक']
# ['राजकारणाची']
# ['राजकारणाचो']
# ['राजकारणाचो']
# ['राजकारणान']
# ['राजकारण्या']
# ['राजकारण्यांची']
# ['राजकारण्याच्या']
# ['राजकी']
# ['राजकी']
# ['राजकी']
# ['राजकी']
# ['राजकी']
# ['राजकी']
# ['राजकी']
# ['राजघराण्यांतलीच']
# ['राजदूत']
# ['राजनाथ']
# ['राजनाथ']
# ['राजनाथ']
# ['राजनाथ']
# ['राजनाथ']
# ['राजनाथ']
# ['राजनाथसिंह']
# ['राजनाथाच्या']
# ['राजनाथान']
# ['राजनाथान']
# ['राजनाथान']
# ['राजनितीचे']
# ['राजभवना']
# ['राजमाता']
# ['राजमातेचें']
# ['राजवट']
# ['राजवटीन']
# ['राजसंधर्शाचीं']
# ['राजस्थान']
# ['राजस्थानची']
# ['राजस्थाना']
# ['राजस्थानांतल्या']
# ['राजस्थानांतल्यान']
# ['राजस्थानाक']
# ['राजस्थानाक']
# ['राजस्थानाच्या']
# ['राजस्थानात']
# ['राजस्थानातल्या']
# ['राजस्थानान']
# ['राजस्थानी']
# ['राजा']
# ['राजा']
# ['राजां']
# ['राजाक']
# ['राजाक']
# ['राजाची']
# ['राजाचें']
# ['राजान']
# ['राजिनामो']
# ['राजिनामो']
# ['राजिनाम्याचो']
# ['राजे']
# ['राजे']
# ['राजे']
# ['राजेंक']
# ['राजेंचो']
# ['राजेक']
# ['राजेक']
# ['राजेक']
# ['राजेचे']
# ['राजेच्या']
# ['राजेन']
# ['राजेन']
# ['राज्य']
# ['राज्य']
# ['राज्यपाल']
# ['राज्यसभेचो']
# ['राज्यसभेतलो']
# ['राज्यांत']
# ['राज्यांत']
# ['राज्यांतलीं']
# ['राणा']
# ['राणे']
# ['राणे']
# ['राणेकूय']
# ['राणेचो']
# ['रातयांत']
# ['रानां']
# ['रावंक']
# ['रावची']
# ['रावचें']
# ['रावचें']
# ['रावचें?']
# ['रावतली']
# ['रावतले']
# ['रावतल्यां']
# ['रावन']
# ['रावन']
# ['रावनात']
# ['रावपाक']
# ['रावपाक']
# ['रावपी']
# ['रावला']
# ['रावल्या']
# ['राष्ट्रपतीचो']
# ['राष्ट्रपिता']
# ['राष्ट्रवादी']
# ['राष्ट्रवादीचे']
# ['राष्ट्रां']
# ['राष्ट्रांचे']
# ['राष्ट्रांनी']
# ['राष्ट्रानी']
# ['राष्ट्रीय']
# ['राष्ट्रीय']
# ['राष्ट्रीय']
# ['राष्ट्रीय']
# ['रासवळ']
# ['रिक्षा']
# ['रितीन']
# ['रुपया']
# ['रुपया']
# ['रुपया']
# ['रुपयांक']
# ['रुपयांचो']
# ['रेंवट']
# ['रेशे']
# ['रोकडा']
# ['रोखडोच']
# ['रोखडोच']
# ['रोजगार']
# ['रोद']
# ['रोस']
# ['रोसाक']
# ['लक्ष']
# ['लक्ष']
# ['लक्षण']
# ['लक्षांत']
# ['लज']
# ['लटक्यो']
# ['लढयली']
# ['लन्न']
# ['लफड्याक']
# ['ललीत']
# ['लश्कर']
# ['लश्कर']
# ['लश्करा']
# ['लश्करा']
# ['लश्कराचो']
# ['लश्करान']
# ['लश्करान']
# ['लश्करी']
# ['लश्करी']
# ['लश्करी']
# ['लश्करी']
# ['लहरी']
# ['लागचो']
# ['लागतलें']
# ['लागता']
# ['लागतात']
# ['लागना']
# ['लागप']
# ['लागपय']
# ['लागपाचे']
# ['लागपाचें']
# ['लागला']
# ['लागला']
# ['लागला']
# ['लागला']
# ['लागला']
# ['लागलां']
# ['लागलां']
# ['लागलां']
# ['लागली']
# ['लागलो']
# ['लागल्या']
# ['लागल्या']
# ['लागल्यांत']
# ['लागल्यात']
# ['लागल्यात']
# ['लागिल्ले']
# ['लागिल्ले']
# ['लागिल्लें']
# ['लागिल्लो']
# ['लागीं']
# ['लागीं']
# ['लागींचे']
# ['लागींचो']
# ['लागू']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागून']
# ['लागे']
# ['लातूर']
# ['लायकेचो']
# ['लायतना']
# ['लायतात']
# ['लायला']
# ['लायलें']
# ['लायलें']
# ['लायल्यात']
# ['लायश्यात']
# ['लालकृष्ण']
# ['लालकृष्ण']
# ['लालकृष्ण']
# ['लालकृष्ण']
# ['लालकृष्ण']
# ['लालू']
# ['लाव']
# ['लावचे']
# ['लावचो']
# ['लावन']
# ['लावन']
# ['लावन']
# ['लावप']
# ['लावपाक']
# ['लावपाक']
# ['लावपाक']
# ['लावपी']
# ['लिजांचें']
# ['लिजार']
# ['लिपून']
# ['लिबेरिया']
# ['लुकसाण']
# ['लेगीत']
# ['लेगीत']
# ['लेगीत']
# ['लेगीत']
# ['लेगीत']
# ['लेगीत']
# ['लॉ']
# ['ल़ॉबी']
# ['लॉबीच्या']
# ['लोक']
# ['लोक']
# ['लोक']
# ['लोक']
# ['लोकप्रतिनिधींक']
# ['लोकमान्य']
# ['लोकशाय']
# ['लोकशाय']
# ['लोकशायवादी']
# ['लोकसभा']
# ['लोकसभा']
# ['लोकसभेच्यो']
# ['लोकां']
# ['लोकांक']
# ['लोकांक']
# ['लोकांक']
# ['लोकांक']
# ['लोकांचें']
# ['लोकांचें']
# ['लोकांच्या']
# ['लोकांच्या']
# ['लोकांच्या']
# ['लोकांच्यो']
# ['लोकांनी']
# ['लोकांनीच']
# ['लोकाक']
# ['लोकाच्या']
# ['ल्हवू']
# ['ल्हवू']
# ['ल्हान']
# ['ल्हान-व्हड']
# ['ल्हारांचो']
# ['वक्तव्यां']
# ['वक्तव्यां']
# ['वक्ल']
# ['वगडायले']
# ['वच']
# ['वचत']
# ['वचना']
# ['वचपाची']
# ['वचपाची']
# ['वचपी']
# ['वचून']
# ['वच्चीं']
# ['वजनदार']
# ['वजें']
# ['वटेन']
# ['वटेन']
# ['वटेन']
# ['वठयिल्ले']
# ['वडे']
# ['वण्टीक']
# ['वतना']
# ['वता']
# ['वता']
# ['वता']
# ['वतात']
# ['वयली']
# ['वयले']
# ['वयलें']
# ['वयलेवयर']
# ['वयलेवयर']
# ['वयलो']
# ['वयल्यांची']
# ['वयल्यांचें']
# ['वयल्यान']
# ['वयल्यान']
# ['वयल्यान']
# ['वयल्यान']
# ['वयल्यान']
# ['वयल्यान']
# ['वयल्यान']
# ['वरणाक']
# ['वरणाचें']
# ['वरदहस्त']
# ['वरयत']
# ['वरी']
# ['वरी']
# ['वरी']
# ['वर्स']
# ['वर्स']
# ['वर्सा']
# ['वर्सा']
# ['वर्सा']
# ['वर्सा']
# ['वर्सा']
# ['वर्सा']
# ['वर्सा']
# ['वर्सा']
# ['वर्सां']
# ['वर्सां']
# ['वर्सां']
# ['वर्सां']
# ['वर्सां']
# ['वर्सां']
# ['वर्सांचे']
# ['वर्सांच्या']
# ['वर्सांनी']
# ['वर्सांनी']
# ['वर्साची']
# ['वर्साची']
# ['वर्साचें']
# ['वर्सावळीची']
# ['वलय']
# ['वलयांकीत']
# ['वल्यान']
# ['वळख']
# ['वळख']
# ['वळखुची']
# ['वळखून']
# ['वळवळटा']
# ['वसुंधरा']
# ['वसुंधरा']
# ['वसुंधरा']
# ['वसुंधरा']
# ['वसुंधरा']
# ['वसुंधरा']
# ['वसुंधरेची']
# ['वसुंधरेचो']
# ['वसुंधरेन']
# ['वसुधंरा']
# ['वस्त']
# ['वा']
# ['वा']
# ['वा']
# ['वा']
# ['वा']
# ['वा']
# ['वा']
# ['वांग']
# ['वांगडाच']
# ['वांगडी']
# ['वांगडीय']
# ['वांगड्यांचे']
# ['वांटप']
# ['वांटपांत']
# ['वांटो']
# ['वांटो']
# ['वांटो']
# ['वांट्याक']
# ['वांयगण्या']
# ['वागपाक']
# ['वागलें']
# ['वाचपाची']
# ['वाजपेयी']
# ['वाजपेयी']
# ['वाजपेयी']
# ['वाजपेयी']
# ['वाजपेयींचे']
# ['वाजपेयींचे']
# ['वाजपेयींच्या']
# ['वाटावपा']
# ['वाटे']
# ['वाटेन']
# ['वाठारांत']
# ['वाठारांनी']
# ['वाड']
# ['वाडटकच']
# ['वाडटली']
# ['वाडटलींच']
# ['वाडटा']
# ['वाडटात']
# ['वाडटात']
# ['वाडटातच']
# ['वाडट्या']
# ['वाडट्या']
# ['वाडत']
# ['वाडत']
# ['वाडयत']
# ['वाडयली']
# ['वाडयिल्लें']
# ['वाडला']
# ['वाडलां']
# ['वाडलां']
# ['वाडलेंना']
# ['वाडल्यात']
# ['वाडीक']
# ['वाडीव']
# ['वाद']
# ['वादतापिल्लो']
# ['वादमोगी']
# ['वादा']
# ['वादाचें']
# ['वायट']
# ['वायट']
# ['वायट']
# ['वायटांतल्यानूय']
# ['वारी']
# ['वारें']
# ['वाळटी']
# ['वाव']
# ['वावर']
# ['वावरा']
# ['वावराक']
# ['वावरूंक']
# ['वावुरता']
# ['वावुरता']
# ['वावुरतात']
# ['वावुरताली']
# ['वावुरले']
# ['वावुरले']
# ['वाशी']
# ['विकते']
# ['विकले']
# ['विकलो']
# ['विकास']
# ['विकास']
# ['विकून']
# ['विकृत']
# ['विक्री']
# ['विखारी']
# ['विघ्नहर्ता']
# ['विचार']
# ['विचार']
# ['विचार']
# ['विचार']
# ['विचार']
# ['विचार']
# ['विचार']
# ['विचारपी?']
# ['विचारलेच']
# ['विचारसरणेक']
# ['विचारां']
# ['विचारिना']
# ['विजया']
# ['विजयाराजेक']
# ['विज्ञान']
# ['विज्ञानान']
# ['विज्ञानीक']
# ['विज्ञानीक']
# ['विटंबणा']
# ['विटंबणा']
# ['विद्यार्थ्यांची']
# ['विधानसभा']
# ['विधानसभेंचीं']
# ['विधानसभेंत']
# ['विधानसभेची']
# ['विधानसभेच्यो']
# ['विधानांपसून']
# ['विध्वंसक']
# ['विध्वंसाचेर']
# ['विनसाळे']
# ['विनोद']
# ['विनोद']
# ['विनोदाचो']
# ['विनोदी']
# ['विभागाचीं']
# ['विमानतळ']
# ['विमानतळ']
# ['विमानतळ']
# ['विमानतळ']
# ['विमानतळा']
# ['विमानतळा']
# ['विमानतळा']
# ['विमानतळाक']
# ['विमानतळाक']
# ['विमानतळाची']
# ['विमानतळाचें']
# ['विमानतळाचेंय']
# ['विमानतळाचेर']
# ['विमानतळाचो']
# ['विमानतळाच्या']
# ['विरांची']
# ['विरुद्ध']
# ['विरेंद्र']
# ['विरोध']
# ['विरोध']
# ['विरोध']
# ['विरोधकांक']
# ['विरोधांत']
# ['विरोधांतल्यान']
# ['विरोधाभास']
# ['विरोधी']
# ['विरोधी']
# ['विरोधी']
# ['विरोधी']
# ['विरोधी']
# ['विलो']
# ['विशय']
# ['विशय']
# ['विशय']
# ['विशयाक']
# ['विशिश्ट']
# ['विशीं']
# ['विशीं']
# ['विशीं']
# ['विशीं']
# ['विशीं']
# ['विशीं']
# ['विशीं']
# ['विशींची']
# ['विशींय']
# ['विशींय']
# ['विश्लेशण']
# ['विश्वजीत']
# ['विसरले']
# ['विसरायेर']
# ['विस्कटावन']
# ['विस्तार']
# ['विस्वास']
# ['विस्वासांत']
# ['वृत्तीक']
# ['वेंग']
# ['वेंगेत']
# ['वेंचणुकांनी']
# ['वेंचणुके']
# ['वेंचणुकेंत']
# ['वेंचणुकेंतल्या']
# ['वेंचणुकेचेर']
# ['वेंचणुकेच्या']
# ['वेंचणूक']
# ['वेंचणूक']
# ['वेंचणूक']
# ['वेंचून']
# ['वेंचून']
# ['वेगळे']
# ['वेगळे']
# ['वेगळे']
# ['वेगळे']
# ['वेगळें']
# ['वेगळें']
# ['वेगळें']
# ['वेगळेच']
# ['वेगळेच']
# ['वेगळो']
# ['वेगवेगळ्या']
# ['वेगवेगळ्यो']
# ['वेचणुकेक']
# ['वेचणुको']
# ['वेचून']
# ['वेठीक']
# ['वेतन']
# ['वेदना']
# ['वेर']
# ['वेळ']
# ['वेळ']
# ['वेळ']
# ['वेळ']
# ['वेळ']
# ['वेळ']
# ['वेळ']
# ['वेळगे']
# ['वेळार']
# ['वेळार']
# ['वेळार']
# ['वेळार']
# ['वेळारूच']
# ['वेवस्थीत']
# ['वेव्हारां']
# ['वेव्हारांचो']
# ['वेव्हारांत']
# ['वेव्हारांत']
# ['वैचणुकेचे']
# ['वैचारीक']
# ['व्यक्तीमत्वातली']
# ['व्या']
# ['व्युव्हरचनेचो']
# ['व्हड']
# ['व्हड']
# ['व्हडले']
# ['व्हडलें']
# ['व्हडलें']
# ['व्हडलेंशें']
# ['व्हडलो']
# ['व्हडलो']
# ['व्हडलो']
# ['व्हडलो']
# ['व्हडलोसो']
# ['व्हरपाचो']
# ['व्हरूंक']
# ['व्हिनान']
# ['शकचो']
# ['शकता']
# ['शकता']
# ['शकता']
# ['शकतात']
# ['शकले']
# ['शक्ती']
# ['शक्तीस्थळां']
# ['शक्य']
# ['शक्य']
# ['शक्य']
# ['शक्य']
# ['शक्यताय']
# ['शय्यासोबत']
# ['शरणम']
# ['शरणम्']
# ['शरद']
# ['शरद']
# ['शरद']
# ['शरसंधान']
# ['शह']
# ['शांतताय']
# ['शांतताय']
# ['शांती']
# ['शाणे']
# ['शाप']
# ['शापोतां']
# ['शिंगार']
# ['शिकयतली']
# ['शिकल्या']
# ['शिकार']
# ['शिकून']
# ['शिगमो']
# ['शिगम्या']
# ['शिगम्यांतलें']
# ['शिगम्याच्या']
# ['शिजतात']
# ['शिजिल्लो']
# ['शिटकाणीय']
# ['शिटकावणी']
# ['शिटकावणी']
# ['शिटकावणी']
# ['शिटकावणी']
# ['शिटकावण्यो']
# ['शिफांरशींचीं']
# ['शिफारशी']
# ['शिमला']
# ['शिमलांतले']
# ['शिमलाचे']
# ['शिश्या']
# ['शिस्तीक']
# ['शिस्तीचे']
# ['शुक्रारा']
# ['शुक्रारा']
# ['शॅनाचेर']
# ['शेंकड्यांत']
# ['शेंकड्यांनी']
# ['शेंदिसना']
# ['शेखावत']
# ['शेखावतां']
# ['शेखावतां']
# ['शेखावताक']
# ['शेखावतान']
# ['शेजारची']
# ['शेजारी']
# ['शेजारी']
# ['शेतांत']
# ['शेती']
# ['शेनवारा']
# ['शॉच्या']
# ['श्रीकृष्णाच्या']
# ['श्रीगणेश']
# ['श्वे']
# ['श्वे']
# ['संकेत']
# ['संकेत']
# ['संक्रमणावस्थेंतल्यान']
# ['संगम']
# ['संघ']
# ['संघ']
# ['संघ']
# ['संघ']
# ['संघ']
# ['संघ']
# ['संघटन']
# ['संघटना']
# ['संघटना']
# ['संघटना']
# ['संघटना']
# ['संघटना']
# ['संघटनांनी']
# ['संघटनाचीय']
# ['संघटनात्मक']
# ['संघम्']
# ['संघर्श']
# ['संघर्श']
# ['संघर्शाक']
# ['संघा']
# ['संघा']
# ['संघा']
# ['संघांतल्यान']
# ['संघाक']
# ['संघाची']
# ['संघाचे']
# ['संघाचे']
# ['संघाचें']
# ['संघाचेरूच']
# ['संघाच्या']
# ['संघाच्या']
# ['संघाच्या']
# ['संघाच्या']
# ['संघान']
# ['संघानूय']
# ['संचार']
# ['संत']
# ['संद']
# ['संद']
# ['संद']
# ['संद']
# ['संद']
# ['संदेश']
# ['संदेश']
# ['संपाचें']
# ['संपादन']
# ['संपादीत']
# ['संपादीत']
# ['संपार']
# ['संबंद']
# ['संबंद']
# ['संबंद']
# ['संबंदीची']
# ['संभावीतपणान']
# ['संभाषण']
# ['संयुक्त']
# ['संयुक्त']
# ['संरक्षण']
# ['संरक्षणा']
# ['संरक्षणा']
# ['संवय']
# ['संवये']
# ['संवयेचो']
# ['संवसार']
# ['संवसारांतले']
# ['संवसारांतलो']
# ['संवसाराक']
# ['संवसारीक']
# ['संविधान']
# ['संस्कारां']
# ['संस्कृतांत']
# ['संस्था']
# ['संस्था']
# ['संस्था']
# ['संस्था']
# ['संस्थानिकांच्या']
# ['संस्थे']
# ['संस्थे']
# ['संस्थेक']
# ['संस्थेकूय']
# ['संस्थेचे']
# ['संस्थेचे']
# ['संस्थेचेर']
# ['संस्थेचो']
# ['संस्थेचो']
# ['संस्थेच्या']
# ['सकयल']
# ['सक्तीचो']
# ['सगळे']
# ['सगळे']
# ['सगळे']
# ['सगळ्या']
# ['सगळ्या']
# ['सगळ्या']
# ['सगळ्या']
# ['सगळ्या']
# ['सगळ्या']
# ['सगळ्यांत']
# ['सगळ्याच']
# ['सगळ्याच']
# ['सज्जनी']
# ['सडो']
# ['सत्ता']
# ['सत्ता']
# ['सत्ताकांक्षा']
# ['सत्ताधारी']
# ['सत्ताधारी']
# ['सत्तेक']
# ['सत्तेच्या']
# ['सत्तेच्या']
# ['सत्तेच्या']
# ['सत्तेपौदा']
# ['सत्तेर']
# ['सत्तेर']
# ['सत्तेर']
# ['सत्रे']
# ['सद']
# ['सदचे']
# ['सदनशीर']
# ['सदळ']
# ['सदळसाणीचें']
# ['सदां']
# ['सदांच']
# ['सदांच']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्या']
# ['सध्याचीं']
# ['सध्याचे']
# ['सध्याचे']
# ['सनातन']
# ['सनातन']
# ['सनातन']
# ['सनातन']
# ['सपन']
# ['सपनां']
# ['सप्टेंबर']
# ['सप्तकांत']
# ['सप्तकाच्या']
# ['समकालीन']
# ['समजुती']
# ['समर्थक']
# ['समर्थक']
# ['समर्थन']
# ['समस्या']
# ['समस्येचें']
# ['समस्येच्या']
# ['समा']
# ['समाज']
# ['समाजकारणाच्या']
# ['समाजविद्धाट्यां']
# ['समाजविद्धाट्यांक']
# ['समाजांत']
# ['समाजांत']
# ['समाजाक']
# ['समाजाक']
# ['समाजाची']
# ['समाजीक']
# ['समाजीक']
# ['समाधान']
# ['समाधान']
# ['समाधान']
# ['समान']
# ['समितीचीय']
# ['समित्यो']
# ['सयत']
# ['सयत']
# ['सयत']
# ['सरंजामशाय']
# ['सरकार']
# ['सरकार']
# ['सरकार']
# ['सरकार']
# ['सरकार']
# ['सरकार']
# ['सरकार']
# ['सरकारा']
# ['सरकारां']
# ['सरकारांत']
# ['सरकाराक']
# ['सरकाराक']
# ['सरकाराक']
# ['सरकाराक']
# ['सरकाराक']
# ['सरकाराचे']
# ['सरकाराच्या']
# ['सरकारान']
# ['सरकारान']
# ['सरकारान']
# ['सरकारान']
# ['सरकारान']
# ['सरकारान']
# ['सरकारान']
# ['सरकारान']
# ['सरकारी']
# ['सरकारी']
# ['सरकारी']
# ['सरचिटणीस']
# ['सरचो']
# ['सरतना']
# ['सरतले']
# ['सरपाक']
# ['सरभोंवतणाच्या']
# ['सरळ']
# ['सरळ']
# ['सरसंघ']
# ['सरसंघचालक']
# ['सरसंघचालक']
# ['सर्ती']
# ['सर्तींत']
# ['सर्वांगी']
# ['सर्वोच̵']
# ['सल्तनतीन']
# ['सवाय']
# ['सव्या']
# ['सशीं']
# ['सशें']
# ['सस्थेच्या']
# ['सांगत']
# ['सांगत']
# ['सांगत']
# ['सांगता']
# ['सांगता']
# ['सांगता']
# ['सांगतात']
# ['सांगतात']
# ['सांगतात']
# ['सांगतात']
# ['सांगप']
# ['सांगप']
# ['सांगप']
# ['सांगप']
# ['सांगपाक']
# ['सांगपाक']
# ['सांगपाक']
# ['सांगपाकूय']
# ['सांगपाचे']
# ['सांगलें']
# ['सांगल्यार']
# ['सांगातान']
# ['सांगून']
# ['सांबाळटना']
# ['सांबाळिल्लें']
# ['सांबाळून']
# ['सांसदाक']
# ['साओ']
# ['साटली']
# ['साठ']
# ['साठ']
# ['साठमारैत']
# ['सात']
# ['सात']
# ['सातशें']
# ['सादतल्यांचो']
# ['सादेसुदै']
# ['सादो']
# ['सादो']
# ['सादो']
# ['साधक']
# ['साधकांचो']
# ['साध्य']
# ['सान']
# ['सान']
# ['सान']
# ['सान']
# ['साबार']
# ['साबार']
# ['साबार']
# ['सामकार']
# ['सामकी']
# ['सामकें']
# ['सामकेच']
# ['सामको']
# ['सामको']
# ['सामक्या']
# ['सामक्यो']
# ['सामाजीक']
# ['सामाजीक']
# ['सामान्या']
# ['सामान्यांक']
# ['सामान्यांचो']
# ['साय']
# ['सारकिलो']
# ['सारकिल्या']
# ['सारकिल्यां']
# ['सारकी']
# ['सारकीं']
# ['सारके']
# ['सारके']
# ['सारके']
# ['सारकें']
# ['सारकें']
# ['सारको']
# ['सारको']
# ['सारक्या']
# ['सारक्या']
# ['सारक्या']
# ['सावटांतल्यान']
# ['सावन']
# ['सावन']
# ['सावन']
# ['सावन']
# ['सावन']
# ['सावन']
# ['सावन']
# ['सावन']
# ['साहिब']
# ['सिंग']
# ['सिंग']
# ['सिंग']
# ['सिंग']
# ['सिंगा']
# ['सिंगांक']
# ['सिंगांच्या']
# ['सिंगाक']
# ['सिंगाचें']
# ['सिंगान']
# ['सिंगान']
# ['सिंगान']
# ['सिंगापूर']
# ['सिंदिया']
# ['सिंधुदुर्ग']
# ['सिद्ध']
# ['सिद्ध']
# ['सिमी']
# ['सीबीआय']
# ['सुकण्यांचीं']
# ['सुको']
# ['सुखराम']
# ['सुचोवण्योय']
# ['सुज्ञ']
# ['सुटके']
# ['सुटत']
# ['सुटना']
# ['सुटना']
# ['सुटयां']
# ['सुटला']
# ['सुटला']
# ['सुटलो']
# ['सुटावो']
# ['सुटाव्यो']
# ['सुट्टात']
# ['सुठना']
# ['सुण्याक']
# ['सुण्यावरी']
# ['सुत्र']
# ['सुत्रां']
# ['सुत्रां']
# ['सुदारीत']
# ['सुदिन']
# ['सुनापरान्तान']
# ['सुपूत']
# ['सुरक्षा']
# ['सुरक्षा']
# ['सुरवात']
# ['सुरू']
# ['सुलूस']
# ['सुळे']
# ['सुळे']
# ['सुळ्यांक']
# ['सुळ्याचो']
# ['सुवात']
# ['सुवातेर']
# ['सुवार्थ']
# ['सुवार्था']
# ['सुवाळोच']
# ['सुवाळ्याक']
# ['सुविधांचो']
# ['से']
# ['सेवेंत']
# ['सेवेच्या']
# ['सोंढये']
# ['सोंपली']
# ['सोंपिल्ल्याची']
# ['सोंपें']
# ['सोंपेपणी']
# ['सोंसचे']
# ['सोडचें']
# ['सोडटात']
# ['सोडपाचो']
# ['सोडली']
# ['सोडलें']
# ['सोडलो']
# ['सोडल्यार']
# ['सोडाच']
# ['सोडिल्ल्या']
# ['सोडीना']
# ['सोडून']
# ['सोद']
# ['सोद']
# ['सोदतनाय']
# ['सोदतल्या']
# ['सोदता']
# ['सोदल्याशी']
# ['सोदिल्ल्या']
# ['सोदून']
# ['सोनिया']
# ['सोनिया']
# ['सोनिया']
# ['सोपतूयबी']
# ['सोपूत']
# ['सोपूत']
# ['सोपूतविधी']
# ['सोपूतविधीचो']
# ['सोबीत']
# ['सोबोवपा']
# ['सोय']
# ['स्टुडन्ट']
# ['स्थान']
# ['स्थानबद्द']
# ['स्थानबद्ध']
# ['स्थानबद्ध']
# ['स्थानबद्धतेचो']
# ['स्थापणुके']
# ['स्थापन']
# ['स्थापन']
# ['स्थापन']
# ['स्थापन']
# ['स्थिती']
# ['स्पश्ट']
# ['स्पश्ट']
# ['स्पश्ट']
# ['स्पश्ट']
# ['स्पश्ट']
# ['स्पश्टीकरण']
# ['स्पेक्ट्रम']
# ['स्पेक्ट्रम्स']
# ['स्फोट']
# ['स्फोट']
# ['स्फोट']
# ['स्फोटा']
# ['स्यू']
# ['स्यू']
# ['स्यू']
# ['स्यू']
# ['स्व']
# ['स्व']
# ['स्वतंत्र']
# ['स्वतंत्र']
# ['स्वता']
# ['स्वताक']
# ['स्वताक']
# ['स्वताच्या']
# ['स्वताच्या']
# ['स्वयंपूर्ण']
# ['स्वयंसेवक']
# ['स्वयंसेवक']
# ['स्वरूप']
# ['स्वरूप']
# ['स्वातंत्र्या']
# ['स्वाभिमानी']
# ['हचबलतेची']
# ['हजर']
# ['हजार']
# ['हजार']
# ['हजारां']
# ['हजारांक']
# ['हडबडीत']
# ['हड्ड्यार']
# ['हतयाचे']
# ['हतयाचे']
# ['हती']
# ['हती']
# ['हत्तीणीच्या']
# ['हत्यार']
# ['हरवेंच']
# ['हरशींय']
# ['हवाला']
# ['हवेचे']
# ['हसकेंत']
# ['हस्तक्षेप']
# ['हस्तीदंत']
# ['हांगा']
# ['हांगाचे']
# ['हांगाय']
# ['हांची']
# ['हांचे']
# ['हांचे']
# ['हांचे']
# ['हांचेप']
# ['हांचेपरस']
# ['हांच्या']
# ['हांणी']
# ['हांणी']
# ['हांतूंत']
# ['हांतूतलें']
# ['हाका']
# ['हाकाच']
# ['हाची']
# ['हाची']
# ['हाची']
# ['हाची']
# ['हाची']
# ['हाची']
# ['हाचीच']
# ['हाचे']
# ['हाचे']
# ['हाचे']
# ['हाचेर']
# ['हाचो']
# ['हाचो']
# ['हाचो']
# ['हाचो']
# ['हाचो']
# ['हाचो']
# ['हाजीर']
# ['हाडचें']
# ['हाडप']
# ['हाडपा']
# ['हाडपाची']
# ['हाडपाची']
# ['हाडपाचो']
# ['हाडपाचो']
# ['हाडलीं']
# ['हाडिल्लो']
# ['हाडून']
# ['हाडून']
# ['हात']
# ['हात']
# ['हात']
# ['हात']
# ['हात']
# ['हात']
# ['हात']
# ['हात']
# ['हात']
# ['हाता']
# ['हातांत']
# ['हातांत']
# ['हातांत']
# ['हातांत']
# ['हातांत']
# ['हातांत']
# ['हातांतली']
# ['हातांतलें']
# ['हातांतल्यान']
# ['हाताक']
# ['हातार']
# ['हाताळ्ळो']
# ['हातूंतलीं']
# ['हातूंतले']
# ['हातूतलीं']
# ['हायकमांडाक']
# ['हायकमांडाक']
# ['हायकमांडाचो']
# ['हायकमांडाच्या']
# ['हाल']
# ['हालचें']
# ['हालींच']
# ['हालींच']
# ['हालींच']
# ['हालींच्या']
# ['हालींच्या']
# ['हालीसाराक']
# ['हालून']
# ['हालोवन']
# ['हावको']
# ['हावळ']
# ['हिंदींत']
# ['हिंदुत्ववादा']
# ['हिंदुत्ववादी']
# ['हिंदुत्वाचो']
# ['हिंदू']
# ['हिंदू']
# ['हिंदू']
# ['हिंदूक']
# ['हिका']
# ['हितराखण']
# ['हितरावण']
# ['हिमाचलांतल्या']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['ही']
# ['हीं']
# ['हीं']
# ['हीं']
# ['हीं']
# ['हीच']
# ['हीच']
# ['हीय']
# ['हुकूमशाय']
# ['हुकूमशाय']
# ['हुकूमशायेचो']
# ['हुस्के']
# ['हुस्को']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हे']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हें']
# ['हेंच']
# ['हेंय']
# ['हेच']
# ['हेता']
# ['हेतू']
# ['हेतू']
# ['हेर']
# ['हेर']
# ['हेर']
# ['हेर']
# ['हेर']
# ['हेर']
# ['हेर']
# ['हेर']
# ['है']
# ['हॉटेलकारांनी']
# ['हॉटेलां']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['हो']
# ['होकर']
# ['होच']
# ['होच']
# ['होच']
# ['होती']
# ['होमगार्डाक']
# ['होमगार्डाचे']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्या']
# ['ह्याच']
# ['ह्यो']
# ['ह्यो']
